# %% [markdown]
# # A2
# ![image.png](attachment:image.png)
# cell 运行总时长 112分钟 59.6秒

# %% [markdown]
# ## A2 cell输出记录
# === resume 检查: A2 ===
#   output_dir: /content/drive/MyDrive/MixUpLLaVA-video-r1/outputs/grpo_A_g8 -> True
#   checkpoints: 无 → 将从头训练
#
# 未找到 checkpoint，将从头训练
# 即将训练 A2 | g=8 | steps=50 | save_steps=10 | out=/content/drive/MyDrive/MixUpLLaVA-video-r1/outputs/grpo_A_g8
# 无 checkpoint，从头训练: /content/drive/MyDrive/MixUpLLaVA-video-r1/outputs/grpo_A_g8
# 执行训练: grpo_A_g8 -> /content/drive/MyDrive/MixUpLLaVA-video-r1/outputs/grpo_A_g8
# 超参: g=8, max_steps=50, frames=2, save_steps=10, resume=False
# (流式日志 + 进度条；Mac 请保持防休眠)
#
# [2026-07-17 05:21:03,777] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# df: /root/.triton/autotune: No such file or directory
# 2026-07-17 05:21:09.699776: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-17 05:21:09.765570: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [2026-07-17 05:21:12,803] [WARNING] [runner.py:215:fetch_hostfile] Unable to find hostfile, will proceed with training with local resources only.
# [2026-07-17 05:21:12,804] [INFO] [runner.py:607:main] cmd = /usr/bin/python3 -u -m deepspeed.launcher.launch --world_info=eyJsb2NhbGhvc3QiOiBbMF19 --master_addr=127.0.0.1 --master_port=29500 --enable_each_rank_log=None /content/drive/MyDrive/MixUpLLaVA-video-r1/repo/TinyLLaVA-Video-R1/tinyllava/train/train.py --deepspeed /content/drive/MyDrive/MixUpLLaVA-video-r1/repo/TinyLLaVA-Video-R1/scripts/zero3_offload.json --video_data_path /content/drive/MyDrive/MixUpLLaVA-video-r1/data/dataset/ --video_folder /content/drive/MyDrive/MixUpLLaVA-video-r1/data/dataset/nextqa_small50.jsonl --is_multimodal True --conv_version qwen2_base --model_name_or_path Qwen/Qwen2.5-3B --vision_tower google/siglip-so400m-patch14-384 --connector_type groupresampler --num_frames 2 --num_queries 32 --mm_vision_select_layer -2 --image_aspect_ratio square --attn_implementation flash_attention_2 --bf16 True --training_recipe common --tune_type_llm full --tune_type_vision_tower frozen --tune_vision_tower_from_layer 0 --tune_type_connector full --group_by_modality_length False --pretrained_model_path /content/drive/MyDrive/MixUpLLaVA-video-r1/checkpoints/coldstart --output_dir /content/drive/MyDrive/MixUpLLaVA-video-r1/outputs/grpo_A_g8 --num_train_epochs 1 --max_steps 50 --per_device_train_batch_size 1 --gradient_accumulation_steps 1 --evaluation_strategy no --learning_rate 5e-6 --weight_decay 0.0 --warmup_ratio 0.03 --lr_scheduler_type cosine --logging_steps 1 --tf32 False --report_to none --model_max_length 256 --gradient_checkpointing True --dataloader_num_workers 2 --lazy_preprocess True --tokenizer_use_fast False --run_name grpo_A_g8 --disable_tqdm False --save_strategy steps --save_steps 10 --save_total_limit 1
# [2026-07-17 05:21:14,579] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2026-07-17 05:21:22,475] [INFO] [launch.py:139:main] 0 NV_LIBNCCL_DEV_PACKAGE=libnccl-dev=2.25.1-1+cuda12.8
# [2026-07-17 05:21:22,475] [INFO] [launch.py:139:main] 0 NV_LIBNCCL_DEV_PACKAGE_VERSION=2.25.1-1
# [2026-07-17 05:21:22,475] [INFO] [launch.py:139:main] 0 NCCL_VERSION=2.25.1-1
# [2026-07-17 05:21:22,475] [INFO] [launch.py:139:main] 0 NV_LIBNCCL_DEV_PACKAGE_NAME=libnccl-dev
# [2026-07-17 05:21:22,475] [INFO] [launch.py:139:main] 0 NV_LIBNCCL_PACKAGE=libnccl2=2.25.1-1+cuda12.8
# [2026-07-17 05:21:22,475] [INFO] [launch.py:139:main] 0 NV_LIBNCCL_PACKAGE_NAME=libnccl2
# [2026-07-17 05:21:22,475] [INFO] [launch.py:139:main] 0 NV_LIBNCCL_PACKAGE_VERSION=2.25.1-1
# [2026-07-17 05:21:22,475] [INFO] [launch.py:146:main] WORLD INFO DICT: {'localhost': [0]}
# [2026-07-17 05:21:22,475] [INFO] [launch.py:152:main] nnodes=1, num_local_procs=1, node_rank=0
# [2026-07-17 05:21:22,475] [INFO] [launch.py:163:main] global_rank_mapping=defaultdict(<class 'list'>, {'localhost': [0]})
# [2026-07-17 05:21:22,475] [INFO] [launch.py:164:main] dist_world_size=1
# [2026-07-17 05:21:22,475] [INFO] [launch.py:168:main] Setting CUDA_VISIBLE_DEVICES=0
# [2026-07-17 05:21:22,476] [INFO] [launch.py:256:main] process 4794 spawned with command: ['/usr/bin/python3', '-u', '/content/drive/MyDrive/MixUpLLaVA-video-r1/repo/TinyLLaVA-Video-R1/tinyllava/train/train.py', '--local_rank=0', '--deepspeed', '/content/drive/MyDrive/MixUpLLaVA-video-r1/repo/TinyLLaVA-Video-R1/scripts/zero3_offload.json', '--video_data_path', '/content/drive/MyDrive/MixUpLLaVA-video-r1/data/dataset/', '--video_folder', '/content/drive/MyDrive/MixUpLLaVA-video-r1/data/dataset/nextqa_small50.jsonl', '--is_multimodal', 'True', '--conv_version', 'qwen2_base', '--model_name_or_path', 'Qwen/Qwen2.5-3B', '--vision_tower', 'google/siglip-so400m-patch14-384', '--connector_type', 'groupresampler', '--num_frames', '2', '--num_queries', '32', '--mm_vision_select_layer', '-2', '--image_aspect_ratio', 'square', '--attn_implementation', 'flash_attention_2', '--bf16', 'True', '--training_recipe', 'common', '--tune_type_llm', 'full', '--tune_type_vision_tower', 'frozen', '--tune_vision_tower_from_layer', '0', '--tune_type_connector', 'full', '--group_by_modality_length', 'False', '--pretrained_model_path', '/content/drive/MyDrive/MixUpLLaVA-video-r1/checkpoints/coldstart', '--output_dir', '/content/drive/MyDrive/MixUpLLaVA-video-r1/outputs/grpo_A_g8', '--num_train_epochs', '1', '--max_steps', '50', '--per_device_train_batch_size', '1', '--gradient_accumulation_steps', '1', '--evaluation_strategy', 'no', '--learning_rate', '5e-6', '--weight_decay', '0.0', '--warmup_ratio', '0.03', '--lr_scheduler_type', 'cosine', '--logging_steps', '1', '--tf32', 'False', '--report_to', 'none', '--model_max_length', '256', '--gradient_checkpointing', 'True', '--dataloader_num_workers', '2', '--lazy_preprocess', 'True', '--tokenizer_use_fast', 'False', '--run_name', 'grpo_A_g8', '--disable_tqdm', 'False', '--save_strategy', 'steps', '--save_steps', '10', '--save_total_limit', '1']
# /content/drive/MyDrive/MixUpLLaVA-video-r1/repo/TinyLLaVA-Video-R1/tinyllava/train/train.py:116: SyntaxWarning: invalid escape sequence '\s'
#   pattern = r"<think>.*?</think>\s*<answer>.*?</answer>"
# [2026-07-17 05:21:38,998] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# /usr/local/lib/python3.12/dist-packages/transformers/training_args.py:1594: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# [2026-07-17 05:22:11,369] [INFO] [comm.py:652:init_distributed] cdb=None
# [2026-07-17 05:22:11,369] [INFO] [comm.py:683:init_distributed] Initializing TorchBackend in DeepSpeed with backend nccl
# [W717 05:22:11.440995425 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [2026-07-17 05:22:14,208] [INFO] [config.py:733:__init__] Config mesh_device None world_size = 1
# Sliding Window Attention is enabled but not implemented for `eager`; unexpected results may be encountered.
# [2026-07-17 05:22:23,710] [INFO] [partition_parameters.py:348:__exit__] finished initializing model - num_params = 921, num_elems = 3.94B
#
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:  50%|█████     | 1/2 [03:00<03:00, 180.96s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [04:24<00:00, 123.87s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [04:24<00:00, 132.44s/it]
#
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 50 examples [00:00, 14460.13 examples/s]
#
# Map:   0%|          | 0/50 [00:00<?, ? examples/s]
# Map: 100%|██████████| 50/50 [00:00<00:00, 5244.19 examples/s]
# [████████████████████████████] 50/50 (100.0%)  elapsed=5.8m  ETA=0.0m
# [2026-07-17 05:26:50,327] [INFO] [config.py:733:__init__] Config mesh_device None world_size = 1
# [2026-07-17 05:26:57,224] [INFO] [partition_parameters.py:348:__exit__] finished initializing model - num_params = 1842, num_elems = 7.88B
#
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:  50%|█████     | 1/2 [00:04<00:04,  4.68s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:07<00:00,  3.58s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:07<00:00,  3.74s/it]
# [2026-07-17 05:27:04,942] [INFO] [logging.py:129:log_dist] [Rank 0] DeepSpeed info: version=0.15.3, git-hash=unknown, git-branch=unknown
# [2026-07-17 05:27:04,942] [INFO] [config.py:733:__init__] Config mesh_device None world_size = 1
# [2026-07-17 05:27:04,959] [INFO] [logging.py:129:log_dist] [Rank 0] DeepSpeed Flops Profiler Enabled: False
# [2026-07-17 05:27:04,962] [INFO] [logging.py:129:log_dist] [Rank 0] Creating ZeRO Offload
# [2026-07-17 05:27:05,326] [INFO] [utils.py:781:see_memory_usage] DeepSpeedZeRoOffload initialize [begin]
# [2026-07-17 05:27:05,327] [INFO] [utils.py:782:see_memory_usage] MA 0.0 GB         Max_MA 1.74 GB         CA 1.76 GB         Max_CA 2 GB
# [2026-07-17 05:27:05,327] [INFO] [utils.py:789:see_memory_usage] CPU Virtual Memory:  used = 26.88 GB, percent = 16.1%
# Parameter Offload: Total persistent parameters: 763328 in 483 params
# [2026-07-17 05:27:05,729] [INFO] [utils.py:781:see_memory_usage] DeepSpeedZeRoOffload initialize [end]
# [2026-07-17 05:27:05,730] [INFO] [utils.py:782:see_memory_usage] MA 0.0 GB         Max_MA 0.0 GB         CA 1.76 GB         Max_CA 2 GB
# [2026-07-17 05:27:05,730] [INFO] [utils.py:789:see_memory_usage] CPU Virtual Memory:  used = 26.89 GB, percent = 16.1%
# [2026-07-17 05:27:05,732] [INFO] [config.py:999:print] DeepSpeedEngine configuration:
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   activation_checkpointing_config  {
#     "partition_activations": false,
#     "contiguous_memory_optimization": false,
#     "cpu_checkpointing": false,
#     "number_checkpoints": null,
#     "synchronize_checkpoint_boundary": false,
#     "profile": false
# }
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   aio_config ................... {'block_size': 1048576, 'queue_depth': 8, 'thread_count': 1, 'single_submit': False, 'overlap_events': True, 'use_gds': False}
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   amp_enabled .................. False
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   amp_params ................... False
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   autotuning_config ............ {
#     "enabled": false,
#     "start_step": null,
#     "end_step": null,
#     "metric_path": null,
#     "arg_mappings": null,
#     "metric": "throughput",
#     "model_info": null,
#     "results_dir": "autotuning_results",
#     "exps_dir": "autotuning_exps",
#     "overwrite": true,
#     "fast": true,
#     "start_profile_step": 3,
#     "end_profile_step": 5,
#     "tuner_type": "gridsearch",
#     "tuner_early_stopping": 5,
#     "tuner_num_trials": 50,
#     "model_info_path": null,
#     "mp_size": 1,
#     "max_train_batch_size": null,
#     "min_train_batch_size": 1,
#     "max_train_micro_batch_size_per_gpu": 1.024000e+03,
#     "min_train_micro_batch_size_per_gpu": 1,
#     "num_tuning_micro_batch_sizes": 3
# }
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   bfloat16_enabled ............. True
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   bfloat16_immediate_grad_update  False
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   checkpoint_parallel_write_pipeline  False
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   checkpoint_tag_validation_enabled  True
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   checkpoint_tag_validation_fail  False
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   comms_config ................. <deepspeed.comm.config.DeepSpeedCommsConfig object at 0x7c3a70759c10>
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   communication_data_type ...... None
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   compression_config ........... {'weight_quantization': {'shared_parameters': {'enabled': False, 'quantizer_kernel': False, 'schedule_offset': 0, 'quantize_groups': 1, 'quantize_verbose': False, 'quantization_type': 'symmetric', 'quantize_weight_in_forward': False, 'rounding': 'nearest', 'fp16_mixed_quantize': False, 'quantize_change_ratio': 0.001}, 'different_groups': {}}, 'activation_quantization': {'shared_parameters': {'enabled': False, 'quantization_type': 'symmetric', 'range_calibration': 'dynamic', 'schedule_offset': 1000}, 'different_groups': {}}, 'sparse_pruning': {'shared_parameters': {'enabled': False, 'method': 'l1', 'schedule_offset': 1000}, 'different_groups': {}}, 'row_pruning': {'shared_parameters': {'enabled': False, 'method': 'l1', 'schedule_offset': 1000}, 'different_groups': {}}, 'head_pruning': {'shared_parameters': {'enabled': False, 'method': 'topk', 'schedule_offset': 1000}, 'different_groups': {}}, 'channel_pruning': {'shared_parameters': {'enabled': False, 'method': 'l1', 'schedule_offset': 1000}, 'different_groups': {}}, 'layer_reduction': {'enabled': False}}
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   curriculum_enabled_legacy .... False
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   curriculum_params_legacy ..... False
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   data_efficiency_config ....... {'enabled': False, 'seed': 1234, 'data_sampling': {'enabled': False, 'num_epochs': 1000, 'num_workers': 0, 'curriculum_learning': {'enabled': False}}, 'data_routing': {'enabled': False, 'random_ltd': {'enabled': False, 'layer_token_lr_schedule': {'enabled': False}}}}
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   data_efficiency_enabled ...... False
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   dataloader_drop_last ......... False
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   disable_allgather ............ False
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   dump_state ................... False
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   dynamic_loss_scale_args ...... None
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   eigenvalue_enabled ........... False
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   eigenvalue_gas_boundary_resolution  1
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   eigenvalue_layer_name ........ bert.encoder.layer
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   eigenvalue_layer_num ......... 0
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   eigenvalue_max_iter .......... 100
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   eigenvalue_stability ......... 1e-06
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   eigenvalue_tol ............... 0.01
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   eigenvalue_verbose ........... False
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   elasticity_enabled ........... False
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   flops_profiler_config ........ {
#     "enabled": false,
#     "recompute_fwd_factor": 0.0,
#     "profile_step": 1,
#     "module_depth": -1,
#     "top_modules": 1,
#     "detailed": true,
#     "output_file": null
# }
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   fp16_auto_cast ............... None
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   fp16_enabled ................. False
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   fp16_master_weights_and_gradients  False
# [2026-07-17 05:27:05,733] [INFO] [config.py:1003:print]   global_rank .................. 0
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   grad_accum_dtype ............. None
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   gradient_accumulation_steps .. 1
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   gradient_clipping ............ 1.0
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   gradient_predivide_factor .... 1.0
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   graph_harvesting ............. False
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   hybrid_engine ................ enabled=False max_out_tokens=512 inference_tp_size=1 release_inference_cache=False pin_parameters=True tp_gather_partition_size=8
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   initial_dynamic_scale ........ 1
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   load_universal_checkpoint .... False
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   loss_scale ................... 1.0
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   memory_breakdown ............. False
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   mics_hierarchial_params_gather  False
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   mics_shard_size .............. -1
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   monitor_config ............... tensorboard=TensorBoardConfig(enabled=False, output_path='', job_name='DeepSpeedJobName') comet=CometConfig(enabled=False, samples_log_interval=100, project=None, workspace=None, api_key=None, experiment_name=None, experiment_key=None, online=None, mode=None) wandb=WandbConfig(enabled=False, group=None, team=None, project='deepspeed') csv_monitor=CSVConfig(enabled=False, output_path='', job_name='DeepSpeedJobName')
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   nebula_config ................ {
#     "enabled": false,
#     "persistent_storage_path": null,
#     "persistent_time_interval": 100,
#     "num_of_version_in_retention": 2,
#     "enable_nebula_load": true,
#     "load_path": null
# }
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   optimizer_legacy_fusion ...... False
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   optimizer_name ............... None
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   optimizer_params ............. None
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   pipeline ..................... {'stages': 'auto', 'partition': 'best', 'seed_layers': False, 'activation_checkpoint_interval': 0, 'pipe_partitioned': True, 'grad_partitioned': True}
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   pld_enabled .................. False
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   pld_params ................... False
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   prescale_gradients ........... False
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   scheduler_name ............... None
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   scheduler_params ............. None
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   seq_parallel_communication_data_type  torch.float32
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   sparse_attention ............. None
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   sparse_gradients_enabled ..... False
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   steps_per_print .............. inf
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   timers_config ................ enabled=True synchronized=True
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   train_batch_size ............. 1
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   train_micro_batch_size_per_gpu  1
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   use_data_before_expert_parallel_  False
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   use_node_local_storage ....... False
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   wall_clock_breakdown ......... False
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   weight_quantization_config ... None
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   world_size ................... 1
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   zero_allow_untested_optimizer  False
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   zero_config .................. stage=3 contiguous_gradients=True reduce_scatter=True reduce_bucket_size=500000000 use_multi_rank_bucket_allreduce=True allgather_partitions=True allgather_bucket_size=500000000 overlap_comm=True load_from_fp32_weights=True elastic_checkpoint=False offload_param=DeepSpeedZeroOffloadParamConfig(device='cpu', nvme_path=None, buffer_count=5, buffer_size=100000000, max_in_cpu=1000000000, pin_memory=True) offload_optimizer=DeepSpeedZeroOffloadOptimizerConfig(device='none', nvme_path=None, buffer_count=4, pin_memory=True, pipeline_read=False, pipeline_write=False, fast_init=False, ratio=1.0) sub_group_size=1000000000 cpu_offload_param=None cpu_offload_use_pin_memory=None cpu_offload=None prefetch_bucket_size=50000000 param_persistence_threshold=100000 model_persistence_threshold=9223372036854775807 max_live_parameters=1000000000 max_reuse_distance=1000000000 gather_16bit_weights_on_model_save=True use_all_reduce_for_fetch_params=False stage3_gather_fp16_weights_on_model_save=False ignore_unused_parameters=True legacy_stage1=False round_robin_gradients=False zero_hpz_partition_size=1 zero_quantized_weights=False zero_quantized_nontrainable_weights=False zero_quantized_gradients=False mics_shard_size=-1 mics_hierarchical_params_gather=False memory_efficient_linear=True pipeline_loading_checkpoint=False override_module_apply=True
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   zero_enabled ................. True
# [2026-07-17 05:27:05,734] [INFO] [config.py:1003:print]   zero_force_ds_cpu_optimizer .. True
# [2026-07-17 05:27:05,735] [INFO] [config.py:1003:print]   zero_optimization_stage ...... 3
# [2026-07-17 05:27:05,735] [INFO] [config.py:989:print_user_config]   json = {
#     "fp16": {
#         "enabled": false,
#         "loss_scale": 0,
#         "loss_scale_window": 1000,
#         "initial_scale_power": 16,
#         "hysteresis": 2,
#         "min_loss_scale": 1
#     },
#     "bf16": {
#         "enabled": true
#     },
#     "zero_optimization": {
#         "stage": 3,
#         "offload_optimizer": {
#             "device": "none",
#             "pin_memory": true
#         },
#         "offload_param": {
#             "device": "cpu",
#             "pin_memory": true
#         },
#         "overlap_comm": true,
#         "contiguous_gradients": true,
#         "sub_group_size": 1.000000e+09,
#         "reduce_bucket_size": "auto",
#         "stage3_prefetch_bucket_size": "auto",
#         "stage3_param_persistence_threshold": "auto",
#         "stage3_max_live_parameters": 1.000000e+09,
#         "stage3_max_reuse_distance": 1.000000e+09,
#         "stage3_gather_16bit_weights_on_model_save": true
#     },
#     "gradient_accumulation_steps": 1,
#     "gradient_clipping": 1.0,
#     "steps_per_print": inf,
#     "train_batch_size": 1,
#     "train_micro_batch_size_per_gpu": 1,
#     "wall_clock_breakdown": false,
#     "zero_optimization.reduce_bucket_size": 4.194304e+06,
#     "zero_optimization.stage3_param_persistence_threshold": 2.048000e+04,
#     "zero_optimization.stage3_prefetch_bucket_size": 3.774874e+06
# }
# Parameter Offload: Total persistent parameters: 697792 in 482 params
#
#   0%|          | 0/50 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
#
#   2%|▏         | 1/50 [02:20<1:55:04, 140.92s/it]
#
# {'loss': -0.0032, 'grad_norm': 4.077493858363646, 'learning_rate': 2.5e-06, 'completion_length': 181.625, 'rewards/accuracy_reward': 0.25, 'rewards/format_reward': 0.6994271278381348, 'reward': -0.32598960399627686, 'reward_std': 1.347003698348999, 'kl': 0.0, 'epoch': 0.02}
#
#   2%|▏         | 1/50 [02:20<1:55:04, 140.92s/it]
#   4%|▍         | 2/50 [04:40<1:52:11, 140.23s/it]
#
# {'loss': 0.0012, 'grad_norm': 5.4300679555388935, 'learning_rate': 5e-06, 'completion_length': 137.875, 'rewards/accuracy_reward': 0.375, 'rewards/format_reward': 0.46041667461395264, 'reward': -0.3084374666213989, 'reward_std': 1.740206003189087, 'kl': 0.0, 'epoch': 0.04}
#
#   4%|▍         | 2/50 [04:40<1:52:11, 140.23s/it]
#   6%|▌         | 3/50 [06:25<1:37:07, 123.99s/it]
#
# {'loss': 0.0061, 'grad_norm': 11.061524651241067, 'learning_rate': 4.994647308096509e-06, 'completion_length': 140.125, 'rewards/accuracy_reward': 0.0, 'rewards/format_reward': 0.4738020598888397, 'reward': -1.223802089691162, 'reward_std': 0.6560043692588806, 'kl': 0.00022029876708984375, 'epoch': 0.06}
#
#   6%|▌         | 3/50 [06:25<1:37:07, 123.99s/it]
#   8%|▊         | 4/50 [08:09<1:29:00, 116.11s/it]
#
# {'loss': 0.0046, 'grad_norm': 5.746790687921609, 'learning_rate': 4.978612153434527e-06, 'completion_length': 141.125, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.5584375262260437, 'reward': -0.7564582824707031, 'reward_std': 1.1493390798568726, 'kl': 0.00051116943359375, 'epoch': 0.08}
#
#   8%|▊         | 4/50 [08:09<1:29:00, 116.11s/it]
#  10%|█         | 5/50 [09:48<1:22:24, 109.87s/it]
#
# {'loss': 0.0029, 'grad_norm': 5.988024578740543, 'learning_rate': 4.9519632010080765e-06, 'completion_length': 130.5, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.3465104103088379, 'reward': -1.0392186641693115, 'reward_std': 1.295461893081665, 'kl': 0.002105712890625, 'epoch': 0.1}
#
#  10%|█         | 5/50 [09:48<1:22:24, 109.87s/it]
#  12%|█▏        | 6/50 [11:51<1:23:50, 114.33s/it]
#
# {'loss': 0.0021, 'grad_norm': 4.023775483288496, 'learning_rate': 4.914814565722671e-06, 'completion_length': 171.75, 'rewards/accuracy_reward': 0.375, 'rewards/format_reward': 0.6535937786102295, 'reward': 0.06338542699813843, 'reward_std': 1.4965004920959473, 'kl': 0.00189971923828125, 'epoch': 0.12}
#
#  12%|█▏        | 6/50 [11:51<1:23:50, 114.33s/it]
#  14%|█▍        | 7/50 [13:17<1:15:16, 105.04s/it]
#
# {'loss': 0.0018, 'grad_norm': 4.713320307474331, 'learning_rate': 4.867325323737765e-06, 'completion_length': 110.375, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.5829687118530273, 'reward': -0.5205729007720947, 'reward_std': 1.0332330465316772, 'kl': 0.004058837890625, 'epoch': 0.14}
#
#  14%|█▍        | 7/50 [13:17<1:15:16, 105.04s/it]
#  16%|█▌        | 8/50 [14:36<1:07:44, 96.78s/it]
#
# {'loss': 0.0002, 'grad_norm': 5.340481606375463, 'learning_rate': 4.809698831278217e-06, 'completion_length': 98.25, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.5157812833786011, 'reward': -0.7021353840827942, 'reward_std': 1.1601085662841797, 'kl': 0.06201171875, 'epoch': 0.16}
#
#  16%|█▌        | 8/50 [14:36<1:07:44, 96.78s/it]
#  18%|█▊        | 9/50 [16:10<1:05:39, 96.08s/it]
#
# {'loss': -0.0096, 'grad_norm': 4.554975746885404, 'learning_rate': 4.742181853831721e-06, 'completion_length': 124.625, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.7106249332427979, 'reward': -0.3970833122730255, 'reward_std': 0.870487630367279, 'kl': 0.00762939453125, 'epoch': 0.18}
#
#  18%|█▊        | 9/50 [16:10<1:05:39, 96.08s/it]
#  20%|██        | 10/50 [17:38<1:02:25, 93.63s/it]
#
# {'loss': 0.0029, 'grad_norm': 4.705555018845463, 'learning_rate': 4.665063509461098e-06, 'completion_length': 108.25, 'rewards/accuracy_reward': 1.0, 'rewards/format_reward': 0.6698958277702332, 'reward': 1.669895887374878, 'reward_std': 0.08544459939002991, 'kl': 0.01336669921875, 'epoch': 0.2}
#
#  20%|██        | 10/50 [17:38<1:02:25, 93.63s/it]/usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#
#  22%|██▏       | 11/50 [21:33<1:28:54, 136.79s/it]
#
# {'loss': -0.006, 'grad_norm': 6.340542885225497, 'learning_rate': 4.578674030756364e-06, 'completion_length': 102.0, 'rewards/accuracy_reward': 0.375, 'rewards/format_reward': 0.6614062786102295, 'reward': 0.16369792819023132, 'reward_std': 1.1901946067810059, 'kl': 0.01904296875, 'epoch': 0.22}
#
#  22%|██▏       | 11/50 [21:33<1:28:54, 136.79s/it]
#  24%|██▍       | 12/50 [23:28<1:22:23, 130.08s/it]
#
# {'loss': -0.0035, 'grad_norm': 4.904241844447955, 'learning_rate': 4.4833833507280884e-06, 'completion_length': 155.75, 'rewards/accuracy_reward': 0.375, 'rewards/format_reward': 0.756301999092102, 'reward': 0.18078124523162842, 'reward_std': 1.3022472858428955, 'kl': 0.0205078125, 'epoch': 0.24}
#
#  24%|██▍       | 12/50 [23:28<1:22:23, 130.08s/it]
#  26%|██▌       | 13/50 [25:09<1:14:54, 121.46s/it]
#
# {'loss': 0.0098, 'grad_norm': 4.6038451497830435, 'learning_rate': 4.379599518697444e-06, 'completion_length': 136.0, 'rewards/accuracy_reward': 0.0, 'rewards/format_reward': 0.7411978840827942, 'reward': -0.7411978840827942, 'reward_std': 0.08167285472154617, 'kl': 0.01708984375, 'epoch': 0.26}
#
#  26%|██▌       | 13/50 [25:09<1:14:54, 121.46s/it]
#  28%|██▊       | 14/50 [27:20<1:14:37, 124.37s/it]
#
# {'loss': -0.0034, 'grad_norm': 3.6929449979075657, 'learning_rate': 4.267766952966369e-06, 'completion_length': 183.0, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.8162500262260437, 'reward': -0.47572916746139526, 'reward_std': 0.9493658542633057, 'kl': 0.0264892578125, 'epoch': 0.28}
#
#  28%|██▊       | 14/50 [27:20<1:14:37, 124.37s/it]
#  30%|███       | 15/50 [29:32<1:13:47, 126.51s/it]
#
# {'loss': 0.0038, 'grad_norm': 4.066146064293696, 'learning_rate': 4.1483645377501726e-06, 'completion_length': 182.375, 'rewards/accuracy_reward': 0.5, 'rewards/format_reward': 0.8113541603088379, 'reward': 0.4726041555404663, 'reward_std': 1.4085614681243896, 'kl': 0.03369140625, 'epoch': 0.3}
#
#  30%|███       | 15/50 [29:32<1:13:47, 126.51s/it]
#  32%|███▏      | 16/50 [30:59<1:04:58, 114.66s/it]
#
# {'loss': -0.0085, 'grad_norm': 5.809221360189782, 'learning_rate': 4.021903572521802e-06, 'completion_length': 107.0, 'rewards/accuracy_reward': 0.375, 'rewards/format_reward': 0.6024999618530273, 'reward': 0.07364585995674133, 'reward_std': 1.450217843055725, 'kl': 0.2431640625, 'epoch': 0.32}
#
#  32%|███▏      | 16/50 [30:59<1:04:58, 114.66s/it]
#  34%|███▍      | 17/50 [33:01<1:04:10, 116.70s/it]
#
# {'loss': -0.0136, 'grad_norm': 5.53719653334835, 'learning_rate': 3.888925582549006e-06, 'completion_length': 167.625, 'rewards/accuracy_reward': 0.0, 'rewards/format_reward': 0.7740625143051147, 'reward': -0.7740625143051147, 'reward_std': 0.12194576859474182, 'kl': 0.04736328125, 'epoch': 0.34}
#
#  34%|███▍      | 17/50 [33:01<1:04:10, 116.70s/it]
#  36%|███▌      | 18/50 [34:44<1:00:03, 112.61s/it]
#
# {'loss': 0.0101, 'grad_norm': 5.18066165420068, 'learning_rate': 3.7500000000000005e-06, 'completion_length': 134.0, 'rewards/accuracy_reward': 0.375, 'rewards/format_reward': 0.7339062690734863, 'reward': 0.2579687535762787, 'reward_std': 1.2991331815719604, 'kl': 0.05859375, 'epoch': 0.36}
#
#  36%|███▌      | 18/50 [34:44<1:00:03, 112.61s/it]
#  38%|███▊      | 19/50 [36:07<53:41, 103.92s/it]
#
# {'loss': -0.0069, 'grad_norm': 6.285867283865887, 'learning_rate': 3.6057217255475034e-06, 'completion_length': 100.375, 'rewards/accuracy_reward': 0.75, 'rewards/format_reward': 0.6592708230018616, 'reward': 1.0958333015441895, 'reward_std': 1.0647650957107544, 'kl': 0.07470703125, 'epoch': 0.38}
#
#  38%|███▊      | 19/50 [36:07<53:41, 103.92s/it]
#  40%|████      | 20/50 [37:56<52:40, 105.36s/it]
#
# {'loss': 0.0047, 'grad_norm': 4.453918625799817, 'learning_rate': 3.4567085809127247e-06, 'completion_length': 147.625, 'rewards/accuracy_reward': 0.5, 'rewards/format_reward': 0.749218761920929, 'reward': 0.49411454796791077, 'reward_std': 1.3371232748031616, 'kl': 0.068359375, 'epoch': 0.4}
#
#  40%|████      | 20/50 [37:56<52:40, 105.36s/it]/usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#
#  42%|████▏     | 21/50 [42:21<1:14:05, 153.31s/it]
#
# {'loss': 0.0038, 'grad_norm': 4.529424139616256, 'learning_rate': 3.303598663257904e-06, 'completion_length': 154.25, 'rewards/accuracy_reward': 0.25, 'rewards/format_reward': 0.7719271183013916, 'reward': -0.0950520932674408, 'reward_std': 1.2055394649505615, 'kl': 0.06298828125, 'epoch': 0.42}
#
#  42%|████▏     | 21/50 [42:21<1:14:05, 153.31s/it]
#  44%|████▍     | 22/50 [44:15<1:06:04, 141.60s/it]
#
# {'loss': -0.0085, 'grad_norm': 4.888037670783515, 'learning_rate': 3.147047612756302e-06, 'completion_length': 155.125, 'rewards/accuracy_reward': 1.0, 'rewards/format_reward': 0.75822913646698, 'reward': 1.7582292556762695, 'reward_std': 0.09873651713132858, 'kl': 0.046875, 'epoch': 0.44}
#
#  44%|████▍     | 22/50 [44:15<1:06:04, 141.60s/it]
#  46%|████▌     | 23/50 [46:10<1:00:01, 133.40s/it]
#
# {'loss': -0.0068, 'grad_norm': 4.632564616322948, 'learning_rate': 2.9877258050403214e-06, 'completion_length': 155.625, 'rewards/accuracy_reward': 0.375, 'rewards/format_reward': 0.7702083587646484, 'reward': 0.19166666269302368, 'reward_std': 1.3216938972473145, 'kl': 0.08056640625, 'epoch': 0.46}
#
#  46%|████▌     | 23/50 [46:10<1:00:01, 133.40s/it]
#  48%|████▊     | 24/50 [48:11<56:16, 129.87s/it]
#
# {'loss': 0.0076, 'grad_norm': 5.4455088810826835, 'learning_rate': 2.82631548055013e-06, 'completion_length': 167.375, 'rewards/accuracy_reward': 0.875, 'rewards/format_reward': 0.7513542175292969, 'reward': 1.4553124904632568, 'reward_std': 0.8788768649101257, 'kl': 0.072265625, 'epoch': 0.48}
#
#  48%|████▊     | 24/50 [48:11<56:16, 129.87s/it]
#  50%|█████     | 25/50 [50:07<52:23, 125.74s/it]
#
# {'loss': 0.0018, 'grad_norm': 4.2206624536833, 'learning_rate': 2.663507823075358e-06, 'completion_length': 153.0, 'rewards/accuracy_reward': 0.375, 'rewards/format_reward': 0.7594270706176758, 'reward': 0.1639062464237213, 'reward_std': 1.3009264469146729, 'kl': 0.07275390625, 'epoch': 0.5}
#
#  50%|█████     | 25/50 [50:07<52:23, 125.74s/it]
#  52%|█████▏    | 26/50 [52:37<53:10, 132.95s/it]
#
# {'loss': -0.0115, 'grad_norm': 3.162944499293231, 'learning_rate': 2.5e-06, 'completion_length': 210.125, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.8261458277702332, 'reward': -0.45114582777023315, 'reward_std': 0.9956347942352295, 'kl': 0.10302734375, 'epoch': 0.52}
#
#  52%|█████▏    | 26/50 [52:37<53:10, 132.95s/it]
#  54%|█████▍    | 27/50 [54:26<48:09, 125.61s/it]
#
# {'loss': -0.0025, 'grad_norm': 5.140689515948391, 'learning_rate': 2.3364921769246423e-06, 'completion_length': 144.0, 'rewards/accuracy_reward': 0.25, 'rewards/format_reward': 0.7472916841506958, 'reward': -0.13812504708766937, 'reward_std': 1.1513468027114868, 'kl': 0.1181640625, 'epoch': 0.54}
#
#  54%|█████▍    | 27/50 [54:26<48:09, 125.61s/it]
#  56%|█████▌    | 28/50 [56:27<45:33, 124.25s/it]
#
# {'loss': 0.0077, 'grad_norm': 4.553381297026958, 'learning_rate': 2.173684519449872e-06, 'completion_length': 165.875, 'rewards/accuracy_reward': 0.5, 'rewards/format_reward': 0.7806249856948853, 'reward': 0.4724999666213989, 'reward_std': 1.3709990978240967, 'kl': 0.107421875, 'epoch': 0.56}
#
#  56%|█████▌    | 28/50 [56:27<45:33, 124.25s/it]
#  58%|█████▊    | 29/50 [58:28<43:07, 123.22s/it]
#
# {'loss': 0.0097, 'grad_norm': 4.284423371805258, 'learning_rate': 2.01227419495968e-06, 'completion_length': 165.75, 'rewards/accuracy_reward': 0.0, 'rewards/format_reward': 0.7960937023162842, 'reward': -0.796093761920929, 'reward_std': 0.123918317258358, 'kl': 0.0849609375, 'epoch': 0.58}
#
#  58%|█████▊    | 29/50 [58:28<43:07, 123.22s/it]
#  60%|██████    | 30/50 [1:00:15<39:27, 118.40s/it]
#
# {'loss': 0.0023, 'grad_norm': 5.601673660109224, 'learning_rate': 1.852952387243698e-06, 'completion_length': 143.5, 'rewards/accuracy_reward': 1.0, 'rewards/format_reward': 0.7510937452316284, 'reward': 1.7510937452316284, 'reward_std': 0.07159014046192169, 'kl': 0.09521484375, 'epoch': 0.6}
#
#  60%|██████    | 30/50 [1:00:15<39:27, 118.40s/it]/usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#
#  62%|██████▏   | 31/50 [1:04:42<51:35, 162.92s/it]
#
# {'loss': -0.0015, 'grad_norm': 4.208626243959632, 'learning_rate': 1.6964013367420967e-06, 'completion_length': 138.375, 'rewards/accuracy_reward': 0.0, 'rewards/format_reward': 0.729687511920929, 'reward': -0.729687511920929, 'reward_std': 0.11753245443105698, 'kl': 0.109375, 'epoch': 0.62}
#
#  62%|██████▏   | 31/50 [1:04:42<51:35, 162.92s/it]
#  64%|██████▍   | 32/50 [1:06:57<46:26, 154.82s/it]
#
# {'loss': 0.0108, 'grad_norm': 3.213906615746581, 'learning_rate': 1.5432914190872757e-06, 'completion_length': 191.125, 'rewards/accuracy_reward': 0.0, 'rewards/format_reward': 0.6565104722976685, 'reward': -0.9065104126930237, 'reward_std': 0.44598010182380676, 'kl': 0.0927734375, 'epoch': 0.64}
#
#  64%|██████▍   | 32/50 [1:06:57<46:26, 154.82s/it]
#  66%|██████▌   | 33/50 [1:09:04<41:27, 146.35s/it]
#
# {'loss': -0.0072, 'grad_norm': 4.910885934105835, 'learning_rate': 1.3942782744524974e-06, 'completion_length': 171.5, 'rewards/accuracy_reward': 0.75, 'rewards/format_reward': 0.7822916507720947, 'reward': 1.173437476158142, 'reward_std': 1.1713632345199585, 'kl': 0.1015625, 'epoch': 0.66}
#
#  66%|██████▌   | 33/50 [1:09:04<41:27, 146.35s/it]
#  68%|██████▊   | 34/50 [1:11:07<37:08, 139.30s/it]
#
# {'loss': -0.0006, 'grad_norm': 4.64666138507985, 'learning_rate': 1.2500000000000007e-06, 'completion_length': 167.125, 'rewards/accuracy_reward': 0.375, 'rewards/format_reward': 0.7876042127609253, 'reward': 0.18416668474674225, 'reward_std': 1.3424415588378906, 'kl': 0.0849609375, 'epoch': 0.68}
#
#  68%|██████▊   | 34/50 [1:11:07<37:08, 139.30s/it]
#  70%|███████   | 35/50 [1:12:48<31:58, 127.92s/it]
#
# {'loss': 0.0133, 'grad_norm': 6.274556499109496, 'learning_rate': 1.1110744174509952e-06, 'completion_length': 131.0, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.7228125333786011, 'reward': -0.42885416746139526, 'reward_std': 0.8515651226043701, 'kl': 0.095703125, 'epoch': 0.7}
#
#  70%|███████   | 35/50 [1:12:48<31:58, 127.92s/it]
#  72%|███████▏  | 36/50 [1:14:50<29:24, 126.01s/it]
#
# {'loss': -0.0018, 'grad_norm': 4.465665535176724, 'learning_rate': 9.780964274781984e-07, 'completion_length': 166.625, 'rewards/accuracy_reward': 0.5, 'rewards/format_reward': 0.7870832681655884, 'reward': 0.510729193687439, 'reward_std': 1.3764859437942505, 'kl': 0.07763671875, 'epoch': 0.72}
#
#  72%|███████▏  | 36/50 [1:14:50<29:24, 126.01s/it]
#  74%|███████▍  | 37/50 [1:16:37<26:03, 120.25s/it]
#
# {'loss': 0.0001, 'grad_norm': 4.880302836224902, 'learning_rate': 8.516354622498279e-07, 'completion_length': 140.25, 'rewards/accuracy_reward': 0.375, 'rewards/format_reward': 0.7291145920753479, 'reward': 0.18838544189929962, 'reward_std': 1.2736070156097412, 'kl': 0.09716796875, 'epoch': 0.74}
#
#  74%|███████▍  | 37/50 [1:16:37<26:03, 120.25s/it]
#  76%|███████▌  | 38/50 [1:18:38<24:08, 120.67s/it]
#
# {'loss': -0.0018, 'grad_norm': 4.346467912479375, 'learning_rate': 7.322330470336314e-07, 'completion_length': 165.0, 'rewards/accuracy_reward': 0.875, 'rewards/format_reward': 0.6814062595367432, 'reward': 1.3064062595367432, 'reward_std': 1.3430196046829224, 'kl': 0.1435546875, 'epoch': 0.76}
#
#  76%|███████▌  | 38/50 [1:18:38<24:08, 120.67s/it]
#  78%|███████▊  | 39/50 [1:20:54<22:56, 125.15s/it]
#
# {'loss': -0.006, 'grad_norm': 3.724949791326616, 'learning_rate': 6.204004813025569e-07, 'completion_length': 190.875, 'rewards/accuracy_reward': 0.875, 'rewards/format_reward': 0.8189061880111694, 'reward': 1.4449479579925537, 'reward_std': 0.9950745701789856, 'kl': 0.11376953125, 'epoch': 0.78}
#
#  78%|███████▊  | 39/50 [1:20:54<22:56, 125.15s/it]
#  80%|████████  | 40/50 [1:22:36<19:41, 118.12s/it]
#
# {'loss': -0.0074, 'grad_norm': 4.673605021463221, 'learning_rate': 5.166166492719124e-07, 'completion_length': 132.625, 'rewards/accuracy_reward': 0.75, 'rewards/format_reward': 0.7251562476158142, 'reward': 1.064843773841858, 'reward_std': 1.1666523218154907, 'kl': 0.103515625, 'epoch': 0.8}
#
#  80%|████████  | 40/50 [1:22:36<19:41, 118.12s/it]/usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#
#  82%|████████▏ | 41/50 [1:26:45<23:38, 157.61s/it]
#
# {'loss': -0.0021, 'grad_norm': 4.402116173090706, 'learning_rate': 4.2132596924363666e-07, 'completion_length': 126.25, 'rewards/accuracy_reward': 0.875, 'rewards/format_reward': 0.71463543176651, 'reward': 1.4166145324707031, 'reward_std': 0.8541903495788574, 'kl': 0.10693359375, 'epoch': 0.82}
#
#  82%|████████▏ | 41/50 [1:26:45<23:38, 157.61s/it]
#  84%|████████▍ | 42/50 [1:28:14<18:14, 136.83s/it]
#
# {'loss': 0.0108, 'grad_norm': 4.927372394911539, 'learning_rate': 3.3493649053890325e-07, 'completion_length': 112.625, 'rewards/accuracy_reward': 0.0, 'rewards/format_reward': 0.6771354675292969, 'reward': -0.6771354079246521, 'reward_std': 0.04342164844274521, 'kl': 0.08837890625, 'epoch': 0.84}
#
#  84%|████████▍ | 42/50 [1:28:14<18:14, 136.83s/it]
#  86%|████████▌ | 43/50 [1:30:22<15:40, 134.38s/it]
#
# {'loss': -0.0059, 'grad_norm': 3.5264414271839466, 'learning_rate': 2.5781814616827936e-07, 'completion_length': 179.875, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.8104166984558105, 'reward': -0.43541666865348816, 'reward_std': 0.9952985048294067, 'kl': 0.09033203125, 'epoch': 0.86}
#
#  86%|████████▌ | 43/50 [1:30:22<15:40, 134.38s/it]
#  88%|████████▊ | 44/50 [1:32:15<12:47, 127.98s/it]
#
# {'loss': 0.0086, 'grad_norm': 5.305269603425587, 'learning_rate': 1.9030116872178317e-07, 'completion_length': 153.25, 'rewards/accuracy_reward': 0.0, 'rewards/format_reward': 0.7723437547683716, 'reward': -0.7723437547683716, 'reward_std': 0.0765351802110672, 'kl': 0.08056640625, 'epoch': 0.88}
#
#  88%|████████▊ | 44/50 [1:32:15<12:47, 127.98s/it]
#  90%|█████████ | 45/50 [1:34:10<10:20, 124.11s/it]
#
# {'loss': 0.0012, 'grad_norm': 3.981138712375355, 'learning_rate': 1.3267467626223606e-07, 'completion_length': 154.875, 'rewards/accuracy_reward': 0.75, 'rewards/format_reward': 0.7714062929153442, 'reward': 1.1055729389190674, 'reward_std': 1.2007641792297363, 'kl': 0.08203125, 'epoch': 0.9}
#
#  90%|█████████ | 45/50 [1:34:10<10:20, 124.11s/it]
#  92%|█████████▏| 46/50 [1:36:07<08:07, 121.76s/it]
#
# {'loss': 0.0017, 'grad_norm': 4.379067185090582, 'learning_rate': 8.518543427732951e-08, 'completion_length': 156.0, 'rewards/accuracy_reward': 0.5, 'rewards/format_reward': 0.7679166793823242, 'reward': 0.5565625429153442, 'reward_std': 1.358523964881897, 'kl': 0.08056640625, 'epoch': 0.92}
#
#  92%|█████████▏| 46/50 [1:36:07<08:07, 121.76s/it]
#  94%|█████████▍| 47/50 [1:37:52<05:50, 116.73s/it]
#
# {'loss': -0.0011, 'grad_norm': 4.220196009041222, 'learning_rate': 4.8036798991923925e-08, 'completion_length': 140.0, 'rewards/accuracy_reward': 0.875, 'rewards/format_reward': 0.7478125095367432, 'reward': 1.4206249713897705, 'reward_std': 0.9021472334861755, 'kl': 0.0751953125, 'epoch': 0.94}
#
#  94%|█████████▍| 47/50 [1:37:52<05:50, 116.73s/it]
#  96%|█████████▌| 48/50 [1:39:38<03:47, 113.74s/it]
#
# {'loss': -0.0051, 'grad_norm': 4.447741751202836, 'learning_rate': 2.1387846565474047e-08, 'completion_length': 142.0, 'rewards/accuracy_reward': 0.0, 'rewards/format_reward': 0.7405729293823242, 'reward': -0.7405729293823242, 'reward_std': 0.09740583598613739, 'kl': 0.10498046875, 'epoch': 0.96}
#
#  96%|█████████▌| 48/50 [1:39:38<03:47, 113.74s/it]
#  98%|█████████▊| 49/50 [1:41:09<01:46, 106.71s/it]
#
# {'loss': 0.0005, 'grad_norm': 5.445371280051156, 'learning_rate': 5.352691903491303e-09, 'completion_length': 115.125, 'rewards/accuracy_reward': 0.625, 'rewards/format_reward': 0.6913020610809326, 'reward': 0.8088021278381348, 'reward_std': 1.233163595199585, 'kl': 0.1435546875, 'epoch': 0.98}
#
#  98%|█████████▊| 49/50 [1:41:09<01:46, 106.71s/it]
# 100%|██████████| 50/50 [1:43:22<00:00, 114.68s/it]
#
# {'loss': 0.0007, 'grad_norm': 3.468262498309436, 'learning_rate': 0.0, 'completion_length': 187.25, 'rewards/accuracy_reward': 0.875, 'rewards/format_reward': 0.8360937237739563, 'reward': 1.4713020324707031, 'reward_std': 0.9889136552810669, 'kl': 0.125, 'epoch': 1.0}
#
# 100%|██████████| 50/50 [1:43:22<00:00, 114.68s/it]
#
# {'train_runtime': 6357.3445, 'train_samples_per_second': 0.008, 'train_steps_per_second': 0.008, 'train_loss': 0.00011755425482988357, 'epoch': 1.0}
#
# 100%|██████████| 50/50 [1:45:57<00:00, 114.68s/it]
# 100%|██████████| 50/50 [1:45:57<00:00, 127.15s/it]
# [2026-07-17 07:13:55,313] [INFO] [launch.py:351:main] Process 4794 exits successfully.
# [████████████████████████████] 50/50 (100.0%)  elapsed=113.0m  ETA=0.0m  done
# 训练完成: /content/drive/MyDrive/MixUpLLaVA-video-r1/outputs/grpo_A_g8 | wall=113.0 min

# %% [markdown]
# # C2
# ![image.png](attachment:image.png)
# cell 运行总时长 83分钟 21.3秒

# %% [markdown]
# ## C2 cell输出记录
# === resume 检查: C2 ===
#   output_dir: /content/drive/MyDrive/MixUpLLaVA-video-r1/outputs/grpo_CPPO_g8_p50 -> False
#   checkpoints: 无 → 将从头训练
#
# 已应用 CPPO 补丁: pruning_rate=0.5, num_generations=8
# 即将训练 C2 | g=8 | steps=50 | save_steps=10 | out=/content/drive/MyDrive/MixUpLLaVA-video-r1/outputs/grpo_CPPO_g8_p50
# 无 checkpoint，从头训练: /content/drive/MyDrive/MixUpLLaVA-video-r1/outputs/grpo_CPPO_g8_p50
# 执行训练: grpo_CPPO_g8_p50 -> /content/drive/MyDrive/MixUpLLaVA-video-r1/outputs/grpo_CPPO_g8_p50
# 超参: g=8, max_steps=50, frames=2, save_steps=10, resume=False
# (流式日志 + 进度条；Mac 请保持防休眠)
#
# [2026-07-17 07:14:05,226] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 2026-07-17 07:14:11.079205: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-17 07:14:11.160685: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [2026-07-17 07:14:14,508] [WARNING] [runner.py:215:fetch_hostfile] Unable to find hostfile, will proceed with training with local resources only.
# [2026-07-17 07:14:14,508] [INFO] [runner.py:607:main] cmd = /usr/bin/python3 -u -m deepspeed.launcher.launch --world_info=eyJsb2NhbGhvc3QiOiBbMF19 --master_addr=127.0.0.1 --master_port=29500 --enable_each_rank_log=None /content/drive/MyDrive/MixUpLLaVA-video-r1/repo/TinyLLaVA-Video-R1/tinyllava/train/train.py --deepspeed /content/drive/MyDrive/MixUpLLaVA-video-r1/repo/TinyLLaVA-Video-R1/scripts/zero3_offload.json --video_data_path /content/drive/MyDrive/MixUpLLaVA-video-r1/data/dataset/ --video_folder /content/drive/MyDrive/MixUpLLaVA-video-r1/data/dataset/nextqa_small50.jsonl --is_multimodal True --conv_version qwen2_base --model_name_or_path Qwen/Qwen2.5-3B --vision_tower google/siglip-so400m-patch14-384 --connector_type groupresampler --num_frames 2 --num_queries 32 --mm_vision_select_layer -2 --image_aspect_ratio square --attn_implementation flash_attention_2 --bf16 True --training_recipe common --tune_type_llm full --tune_type_vision_tower frozen --tune_vision_tower_from_layer 0 --tune_type_connector full --group_by_modality_length False --pretrained_model_path /content/drive/MyDrive/MixUpLLaVA-video-r1/checkpoints/coldstart --output_dir /content/drive/MyDrive/MixUpLLaVA-video-r1/outputs/grpo_CPPO_g8_p50 --num_train_epochs 1 --max_steps 50 --per_device_train_batch_size 1 --gradient_accumulation_steps 1 --evaluation_strategy no --learning_rate 5e-6 --weight_decay 0.0 --warmup_ratio 0.03 --lr_scheduler_type cosine --logging_steps 1 --tf32 False --report_to none --model_max_length 256 --gradient_checkpointing True --dataloader_num_workers 2 --lazy_preprocess True --tokenizer_use_fast False --run_name grpo_CPPO_g8_p50 --disable_tqdm False --save_strategy steps --save_steps 10 --save_total_limit 1
# [2026-07-17 07:14:16,509] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2026-07-17 07:14:24,685] [INFO] [launch.py:139:main] 0 NV_LIBNCCL_DEV_PACKAGE=libnccl-dev=2.25.1-1+cuda12.8
# [2026-07-17 07:14:24,685] [INFO] [launch.py:139:main] 0 NV_LIBNCCL_DEV_PACKAGE_VERSION=2.25.1-1
# [2026-07-17 07:14:24,685] [INFO] [launch.py:139:main] 0 NCCL_VERSION=2.25.1-1
# [2026-07-17 07:14:24,685] [INFO] [launch.py:139:main] 0 NV_LIBNCCL_DEV_PACKAGE_NAME=libnccl-dev
# [2026-07-17 07:14:24,685] [INFO] [launch.py:139:main] 0 NV_LIBNCCL_PACKAGE=libnccl2=2.25.1-1+cuda12.8
# [2026-07-17 07:14:24,685] [INFO] [launch.py:139:main] 0 NV_LIBNCCL_PACKAGE_NAME=libnccl2
# [2026-07-17 07:14:24,685] [INFO] [launch.py:139:main] 0 NV_LIBNCCL_PACKAGE_VERSION=2.25.1-1
# [2026-07-17 07:14:24,685] [INFO] [launch.py:146:main] WORLD INFO DICT: {'localhost': [0]}
# [2026-07-17 07:14:24,685] [INFO] [launch.py:152:main] nnodes=1, num_local_procs=1, node_rank=0
# [2026-07-17 07:14:24,685] [INFO] [launch.py:163:main] global_rank_mapping=defaultdict(<class 'list'>, {'localhost': [0]})
# [2026-07-17 07:14:24,685] [INFO] [launch.py:164:main] dist_world_size=1
# [2026-07-17 07:14:24,685] [INFO] [launch.py:168:main] Setting CUDA_VISIBLE_DEVICES=0
# [2026-07-17 07:14:24,686] [INFO] [launch.py:256:main] process 33646 spawned with command: ['/usr/bin/python3', '-u', '/content/drive/MyDrive/MixUpLLaVA-video-r1/repo/TinyLLaVA-Video-R1/tinyllava/train/train.py', '--local_rank=0', '--deepspeed', '/content/drive/MyDrive/MixUpLLaVA-video-r1/repo/TinyLLaVA-Video-R1/scripts/zero3_offload.json', '--video_data_path', '/content/drive/MyDrive/MixUpLLaVA-video-r1/data/dataset/', '--video_folder', '/content/drive/MyDrive/MixUpLLaVA-video-r1/data/dataset/nextqa_small50.jsonl', '--is_multimodal', 'True', '--conv_version', 'qwen2_base', '--model_name_or_path', 'Qwen/Qwen2.5-3B', '--vision_tower', 'google/siglip-so400m-patch14-384', '--connector_type', 'groupresampler', '--num_frames', '2', '--num_queries', '32', '--mm_vision_select_layer', '-2', '--image_aspect_ratio', 'square', '--attn_implementation', 'flash_attention_2', '--bf16', 'True', '--training_recipe', 'common', '--tune_type_llm', 'full', '--tune_type_vision_tower', 'frozen', '--tune_vision_tower_from_layer', '0', '--tune_type_connector', 'full', '--group_by_modality_length', 'False', '--pretrained_model_path', '/content/drive/MyDrive/MixUpLLaVA-video-r1/checkpoints/coldstart', '--output_dir', '/content/drive/MyDrive/MixUpLLaVA-video-r1/outputs/grpo_CPPO_g8_p50', '--num_train_epochs', '1', '--max_steps', '50', '--per_device_train_batch_size', '1', '--gradient_accumulation_steps', '1', '--evaluation_strategy', 'no', '--learning_rate', '5e-6', '--weight_decay', '0.0', '--warmup_ratio', '0.03', '--lr_scheduler_type', 'cosine', '--logging_steps', '1', '--tf32', 'False', '--report_to', 'none', '--model_max_length', '256', '--gradient_checkpointing', 'True', '--dataloader_num_workers', '2', '--lazy_preprocess', 'True', '--tokenizer_use_fast', 'False', '--run_name', 'grpo_CPPO_g8_p50', '--disable_tqdm', 'False', '--save_strategy', 'steps', '--save_steps', '10', '--save_total_limit', '1']
# /content/drive/MyDrive/MixUpLLaVA-video-r1/repo/TinyLLaVA-Video-R1/tinyllava/train/train.py:116: SyntaxWarning: invalid escape sequence '\s'
#   pattern = r"<think>.*?</think>\s*<answer>.*?</answer>"
# [2026-07-17 07:14:39,586] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# /usr/local/lib/python3.12/dist-packages/transformers/training_args.py:1594: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# [2026-07-17 07:15:08,579] [INFO] [comm.py:652:init_distributed] cdb=None
# [2026-07-17 07:15:08,579] [INFO] [comm.py:683:init_distributed] Initializing TorchBackend in DeepSpeed with backend nccl
# [W717 07:15:08.650789561 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [2026-07-17 07:15:11,119] [INFO] [config.py:733:__init__] Config mesh_device None world_size = 1
# Sliding Window Attention is enabled but not implemented for `eager`; unexpected results may be encountered.
# [2026-07-17 07:15:19,374] [INFO] [partition_parameters.py:348:__exit__] finished initializing model - num_params = 921, num_elems = 3.94B
#
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:  50%|█████     | 1/2 [02:26<02:26, 146.98s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [03:36<00:00, 101.54s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [03:36<00:00, 108.36s/it]
# [2026-07-17 07:18:57,710] [INFO] [config.py:733:__init__] Config mesh_device None world_size = 1
# [2026-07-17 07:19:05,433] [INFO] [partition_parameters.py:348:__exit__] finished initializing model - num_params = 1842, num_elems = 7.88B
#
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:  50%|█████     | 1/2 [00:05<00:05,  5.11s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:08<00:00,  3.82s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:08<00:00,  4.01s/it]
# [2026-07-17 07:19:13,700] [INFO] [logging.py:129:log_dist] [Rank 0] DeepSpeed info: version=0.15.3, git-hash=unknown, git-branch=unknown
# [2026-07-17 07:19:13,700] [INFO] [config.py:733:__init__] Config mesh_device None world_size = 1
# [2026-07-17 07:19:13,716] [INFO] [logging.py:129:log_dist] [Rank 0] DeepSpeed Flops Profiler Enabled: False
# [2026-07-17 07:19:13,719] [INFO] [logging.py:129:log_dist] [Rank 0] Creating ZeRO Offload
# [2026-07-17 07:19:14,087] [INFO] [utils.py:781:see_memory_usage] DeepSpeedZeRoOffload initialize [begin]
# [2026-07-17 07:19:14,087] [INFO] [utils.py:782:see_memory_usage] MA 0.0 GB         Max_MA 1.74 GB         CA 1.76 GB         Max_CA 2 GB
# [2026-07-17 07:19:14,088] [INFO] [utils.py:789:see_memory_usage] CPU Virtual Memory:  used = 27.04 GB, percent = 16.2%
# Parameter Offload: Total persistent parameters: 763328 in 483 params
# [2026-07-17 07:19:14,504] [INFO] [utils.py:781:see_memory_usage] DeepSpeedZeRoOffload initialize [end]
# [2026-07-17 07:19:14,504] [INFO] [utils.py:782:see_memory_usage] MA 0.0 GB         Max_MA 0.0 GB         CA 1.76 GB         Max_CA 2 GB
# [2026-07-17 07:19:14,505] [INFO] [utils.py:789:see_memory_usage] CPU Virtual Memory:  used = 27.06 GB, percent = 16.2%
# [2026-07-17 07:19:14,507] [INFO] [config.py:999:print] DeepSpeedEngine configuration:
# [2026-07-17 07:19:14,507] [INFO] [config.py:1003:print]   activation_checkpointing_config  {
#     "partition_activations": false,
#     "contiguous_memory_optimization": false,
#     "cpu_checkpointing": false,
#     "number_checkpoints": null,
#     "synchronize_checkpoint_boundary": false,
#     "profile": false
# }
# [2026-07-17 07:19:14,507] [INFO] [config.py:1003:print]   aio_config ................... {'block_size': 1048576, 'queue_depth': 8, 'thread_count': 1, 'single_submit': False, 'overlap_events': True, 'use_gds': False}
# [2026-07-17 07:19:14,507] [INFO] [config.py:1003:print]   amp_enabled .................. False
# [2026-07-17 07:19:14,507] [INFO] [config.py:1003:print]   amp_params ................... False
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   autotuning_config ............ {
#     "enabled": false,
#     "start_step": null,
#     "end_step": null,
#     "metric_path": null,
#     "arg_mappings": null,
#     "metric": "throughput",
#     "model_info": null,
#     "results_dir": "autotuning_results",
#     "exps_dir": "autotuning_exps",
#     "overwrite": true,
#     "fast": true,
#     "start_profile_step": 3,
#     "end_profile_step": 5,
#     "tuner_type": "gridsearch",
#     "tuner_early_stopping": 5,
#     "tuner_num_trials": 50,
#     "model_info_path": null,
#     "mp_size": 1,
#     "max_train_batch_size": null,
#     "min_train_batch_size": 1,
#     "max_train_micro_batch_size_per_gpu": 1.024000e+03,
#     "min_train_micro_batch_size_per_gpu": 1,
#     "num_tuning_micro_batch_sizes": 3
# }
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   bfloat16_enabled ............. True
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   bfloat16_immediate_grad_update  False
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   checkpoint_parallel_write_pipeline  False
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   checkpoint_tag_validation_enabled  True
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   checkpoint_tag_validation_fail  False
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   comms_config ................. <deepspeed.comm.config.DeepSpeedCommsConfig object at 0x7bf14a5eb1a0>
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   communication_data_type ...... None
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   compression_config ........... {'weight_quantization': {'shared_parameters': {'enabled': False, 'quantizer_kernel': False, 'schedule_offset': 0, 'quantize_groups': 1, 'quantize_verbose': False, 'quantization_type': 'symmetric', 'quantize_weight_in_forward': False, 'rounding': 'nearest', 'fp16_mixed_quantize': False, 'quantize_change_ratio': 0.001}, 'different_groups': {}}, 'activation_quantization': {'shared_parameters': {'enabled': False, 'quantization_type': 'symmetric', 'range_calibration': 'dynamic', 'schedule_offset': 1000}, 'different_groups': {}}, 'sparse_pruning': {'shared_parameters': {'enabled': False, 'method': 'l1', 'schedule_offset': 1000}, 'different_groups': {}}, 'row_pruning': {'shared_parameters': {'enabled': False, 'method': 'l1', 'schedule_offset': 1000}, 'different_groups': {}}, 'head_pruning': {'shared_parameters': {'enabled': False, 'method': 'topk', 'schedule_offset': 1000}, 'different_groups': {}}, 'channel_pruning': {'shared_parameters': {'enabled': False, 'method': 'l1', 'schedule_offset': 1000}, 'different_groups': {}}, 'layer_reduction': {'enabled': False}}
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   curriculum_enabled_legacy .... False
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   curriculum_params_legacy ..... False
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   data_efficiency_config ....... {'enabled': False, 'seed': 1234, 'data_sampling': {'enabled': False, 'num_epochs': 1000, 'num_workers': 0, 'curriculum_learning': {'enabled': False}}, 'data_routing': {'enabled': False, 'random_ltd': {'enabled': False, 'layer_token_lr_schedule': {'enabled': False}}}}
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   data_efficiency_enabled ...... False
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   dataloader_drop_last ......... False
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   disable_allgather ............ False
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   dump_state ................... False
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   dynamic_loss_scale_args ...... None
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   eigenvalue_enabled ........... False
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   eigenvalue_gas_boundary_resolution  1
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   eigenvalue_layer_name ........ bert.encoder.layer
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   eigenvalue_layer_num ......... 0
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   eigenvalue_max_iter .......... 100
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   eigenvalue_stability ......... 1e-06
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   eigenvalue_tol ............... 0.01
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   eigenvalue_verbose ........... False
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   elasticity_enabled ........... False
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   flops_profiler_config ........ {
#     "enabled": false,
#     "recompute_fwd_factor": 0.0,
#     "profile_step": 1,
#     "module_depth": -1,
#     "top_modules": 1,
#     "detailed": true,
#     "output_file": null
# }
# [2026-07-17 07:19:14,508] [INFO] [config.py:1003:print]   fp16_auto_cast ............... None
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   fp16_enabled ................. False
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   fp16_master_weights_and_gradients  False
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   global_rank .................. 0
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   grad_accum_dtype ............. None
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   gradient_accumulation_steps .. 1
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   gradient_clipping ............ 1.0
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   gradient_predivide_factor .... 1.0
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   graph_harvesting ............. False
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   hybrid_engine ................ enabled=False max_out_tokens=512 inference_tp_size=1 release_inference_cache=False pin_parameters=True tp_gather_partition_size=8
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   initial_dynamic_scale ........ 1
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   load_universal_checkpoint .... False
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   loss_scale ................... 1.0
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   memory_breakdown ............. False
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   mics_hierarchial_params_gather  False
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   mics_shard_size .............. -1
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   monitor_config ............... tensorboard=TensorBoardConfig(enabled=False, output_path='', job_name='DeepSpeedJobName') comet=CometConfig(enabled=False, samples_log_interval=100, project=None, workspace=None, api_key=None, experiment_name=None, experiment_key=None, online=None, mode=None) wandb=WandbConfig(enabled=False, group=None, team=None, project='deepspeed') csv_monitor=CSVConfig(enabled=False, output_path='', job_name='DeepSpeedJobName')
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   nebula_config ................ {
#     "enabled": false,
#     "persistent_storage_path": null,
#     "persistent_time_interval": 100,
#     "num_of_version_in_retention": 2,
#     "enable_nebula_load": true,
#     "load_path": null
# }
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   optimizer_legacy_fusion ...... False
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   optimizer_name ............... None
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   optimizer_params ............. None
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   pipeline ..................... {'stages': 'auto', 'partition': 'best', 'seed_layers': False, 'activation_checkpoint_interval': 0, 'pipe_partitioned': True, 'grad_partitioned': True}
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   pld_enabled .................. False
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   pld_params ................... False
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   prescale_gradients ........... False
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   scheduler_name ............... None
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   scheduler_params ............. None
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   seq_parallel_communication_data_type  torch.float32
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   sparse_attention ............. None
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   sparse_gradients_enabled ..... False
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   steps_per_print .............. inf
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   timers_config ................ enabled=True synchronized=True
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   train_batch_size ............. 1
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   train_micro_batch_size_per_gpu  1
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   use_data_before_expert_parallel_  False
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   use_node_local_storage ....... False
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   wall_clock_breakdown ......... False
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   weight_quantization_config ... None
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   world_size ................... 1
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   zero_allow_untested_optimizer  False
# [2026-07-17 07:19:14,509] [INFO] [config.py:1003:print]   zero_config .................. stage=3 contiguous_gradients=True reduce_scatter=True reduce_bucket_size=500000000 use_multi_rank_bucket_allreduce=True allgather_partitions=True allgather_bucket_size=500000000 overlap_comm=True load_from_fp32_weights=True elastic_checkpoint=False offload_param=DeepSpeedZeroOffloadParamConfig(device='cpu', nvme_path=None, buffer_count=5, buffer_size=100000000, max_in_cpu=1000000000, pin_memory=True) offload_optimizer=DeepSpeedZeroOffloadOptimizerConfig(device='none', nvme_path=None, buffer_count=4, pin_memory=True, pipeline_read=False, pipeline_write=False, fast_init=False, ratio=1.0) sub_group_size=1000000000 cpu_offload_param=None cpu_offload_use_pin_memory=None cpu_offload=None prefetch_bucket_size=50000000 param_persistence_threshold=100000 model_persistence_threshold=9223372036854775807 max_live_parameters=1000000000 max_reuse_distance=1000000000 gather_16bit_weights_on_model_save=True use_all_reduce_for_fetch_params=False stage3_gather_fp16_weights_on_model_save=False ignore_unused_parameters=True legacy_stage1=False round_robin_gradients=False zero_hpz_partition_size=1 zero_quantized_weights=False zero_quantized_nontrainable_weights=False zero_quantized_gradients=False mics_shard_size=-1 mics_hierarchical_params_gather=False memory_efficient_linear=True pipeline_loading_checkpoint=False override_module_apply=True
# [2026-07-17 07:19:14,510] [INFO] [config.py:1003:print]   zero_enabled ................. True
# [2026-07-17 07:19:14,510] [INFO] [config.py:1003:print]   zero_force_ds_cpu_optimizer .. True
# [2026-07-17 07:19:14,510] [INFO] [config.py:1003:print]   zero_optimization_stage ...... 3
# [2026-07-17 07:19:14,510] [INFO] [config.py:989:print_user_config]   json = {
#     "fp16": {
#         "enabled": false,
#         "loss_scale": 0,
#         "loss_scale_window": 1000,
#         "initial_scale_power": 16,
#         "hysteresis": 2,
#         "min_loss_scale": 1
#     },
#     "bf16": {
#         "enabled": true
#     },
#     "zero_optimization": {
#         "stage": 3,
#         "offload_optimizer": {
#             "device": "none",
#             "pin_memory": true
#         },
#         "offload_param": {
#             "device": "cpu",
#             "pin_memory": true
#         },
#         "overlap_comm": true,
#         "contiguous_gradients": true,
#         "sub_group_size": 1.000000e+09,
#         "reduce_bucket_size": "auto",
#         "stage3_prefetch_bucket_size": "auto",
#         "stage3_param_persistence_threshold": "auto",
#         "stage3_max_live_parameters": 1.000000e+09,
#         "stage3_max_reuse_distance": 1.000000e+09,
#         "stage3_gather_16bit_weights_on_model_save": true
#     },
#     "gradient_accumulation_steps": 1,
#     "gradient_clipping": 1.0,
#     "steps_per_print": inf,
#     "train_batch_size": 1,
#     "train_micro_batch_size_per_gpu": 1,
#     "wall_clock_breakdown": false,
#     "zero_optimization.reduce_bucket_size": 4.194304e+06,
#     "zero_optimization.stage3_param_persistence_threshold": 2.048000e+04,
#     "zero_optimization.stage3_prefetch_bucket_size": 3.774874e+06
# }
# Parameter Offload: Total persistent parameters: 697792 in 482 params
#
#   0%|          | 0/50 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
#
#   2%|▏         | 1/50 [02:21<1:55:40, 141.64s/it]
# [░░░░░░░░░░░░░░░░░░░░░░░░░░░░] 1/50 (  2.0%)  elapsed=7.7m  ETA=379.6m
#
# {'loss': -0.3353, 'grad_norm': 7.970162502807614, 'learning_rate': 2.5e-06, 'completion_length': 196.25, 'rewards/accuracy_reward': 0.25, 'rewards/format_reward': 0.6994271278381348, 'reward': -0.32598960399627686, 'reward_std': 1.347003698348999, 'kl': 0.0, 'epoch': 0.02}
#
#   2%|▏         | 1/50 [02:21<1:55:40, 141.64s/it]
#   4%|▍         | 2/50 [04:22<1:43:30, 129.39s/it]
# [█░░░░░░░░░░░░░░░░░░░░░░░░░░░] 2/50 (  4.0%)  elapsed=9.8m  ETA=234.3m
#
# {'loss': -0.6295, 'grad_norm': 9.764150200056358, 'learning_rate': 5e-06, 'completion_length': 107.0, 'rewards/accuracy_reward': 0.375, 'rewards/format_reward': 0.46041667461395264, 'reward': -0.3084374666213989, 'reward_std': 1.740206003189087, 'kl': 0.0, 'epoch': 0.04}
#
#   4%|▍         | 2/50 [04:22<1:43:30, 129.39s/it]
#   6%|▌         | 3/50 [06:20<1:37:26, 124.39s/it]
# [█░░░░░░░░░░░░░░░░░░░░░░░░░░░] 3/50 (  6.0%)  elapsed=11.7m  ETA=183.9m
#
# {'loss': 0.4476, 'grad_norm': 7.596306014439101, 'learning_rate': 4.994647308096509e-06, 'completion_length': 158.5, 'rewards/accuracy_reward': 0.0, 'rewards/format_reward': 0.5646874904632568, 'reward': -1.0646874904632568, 'reward_std': 0.5854018330574036, 'kl': 0.0003566741943359375, 'epoch': 0.06}
#
#   6%|▌         | 3/50 [06:20<1:37:26, 124.39s/it]
#   8%|▊         | 4/50 [08:24<1:35:00, 123.92s/it]
# [██░░░░░░░░░░░░░░░░░░░░░░░░░░] 4/50 (  8.0%)  elapsed=13.8m  ETA=158.6m
#
# {'loss': -0.0695, 'grad_norm': 7.468080672849791, 'learning_rate': 4.978612153434527e-06, 'completion_length': 232.0, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.6706250309944153, 'reward': -0.5859375, 'reward_std': 1.0789753198623657, 'kl': 0.000701904296875, 'epoch': 0.08}
#
#   8%|▊         | 4/50 [08:24<1:35:00, 123.92s/it]
#  10%|█         | 5/50 [10:02<1:25:57, 114.62s/it]
# [██░░░░░░░░░░░░░░░░░░░░░░░░░░] 5/50 ( 10.0%)  elapsed=15.4m  ETA=138.8m
#
# {'loss': -0.1897, 'grad_norm': 8.511561340990095, 'learning_rate': 4.9519632010080765e-06, 'completion_length': 165.25, 'rewards/accuracy_reward': 0.25, 'rewards/format_reward': 0.52755206823349, 'reward': -0.3877604305744171, 'reward_std': 1.4607030153274536, 'kl': 0.0012054443359375, 'epoch': 0.1}
#
#  10%|█         | 5/50 [10:02<1:25:57, 114.62s/it]
#  12%|█▏        | 6/50 [12:22<1:30:29, 123.40s/it]
# [███░░░░░░░░░░░░░░░░░░░░░░░░░] 6/50 ( 12.0%)  elapsed=17.8m  ETA=130.3m
#
# {'loss': -0.2525, 'grad_norm': 7.580570052845677, 'learning_rate': 4.914814565722671e-06, 'completion_length': 241.25, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.8429166078567505, 'reward': -0.5110416412353516, 'reward_std': 0.9498233795166016, 'kl': 0.0015106201171875, 'epoch': 0.12}
#
#  12%|█▏        | 6/50 [12:22<1:30:29, 123.40s/it]
#  14%|█▍        | 7/50 [13:52<1:20:32, 112.39s/it]
# [███░░░░░░░░░░░░░░░░░░░░░░░░░] 7/50 ( 14.0%)  elapsed=19.3m  ETA=118.3m
#
# {'loss': 0.1885, 'grad_norm': 16.312519794200806, 'learning_rate': 4.867325323737765e-06, 'completion_length': 124.25, 'rewards/accuracy_reward': 0.5, 'rewards/format_reward': 0.51583331823349, 'reward': 0.19447915256023407, 'reward_std': 1.7003856897354126, 'kl': 0.0037841796875, 'epoch': 0.14}
#
#  14%|█▍        | 7/50 [13:52<1:20:32, 112.39s/it]
#  16%|█▌        | 8/50 [15:12<1:11:31, 102.17s/it]
# [████░░░░░░░░░░░░░░░░░░░░░░░░] 8/50 ( 16.0%)  elapsed=20.6m  ETA=108.1m
#
# {'loss': 0.6306, 'grad_norm': 8.004885299916012, 'learning_rate': 4.809698831278217e-06, 'completion_length': 113.0, 'rewards/accuracy_reward': 0.625, 'rewards/format_reward': 0.49140626192092896, 'reward': 0.634218692779541, 'reward_std': 1.0946625471115112, 'kl': 0.010498046875, 'epoch': 0.16}
#
#  16%|█▌        | 8/50 [15:12<1:11:31, 102.17s/it]
#  18%|█▊        | 9/50 [16:48<1:08:25, 100.15s/it]
# [█████░░░░░░░░░░░░░░░░░░░░░░░] 9/50 ( 18.0%)  elapsed=22.2m  ETA=101.1m
#
# {'loss': 0.009, 'grad_norm': 10.703814704852766, 'learning_rate': 4.742181853831721e-06, 'completion_length': 130.5, 'rewards/accuracy_reward': 0.375, 'rewards/format_reward': 0.5533853769302368, 'reward': -0.12140625715255737, 'reward_std': 1.6320022344589233, 'kl': 0.01373291015625, 'epoch': 0.18}
#
#  18%|█▊        | 9/50 [16:48<1:08:25, 100.15s/it]
#  20%|██        | 10/50 [18:08<1:02:38, 93.97s/it]
# [█████░░░░░░░░░░░░░░░░░░░░░░░] 10/50 ( 20.0%)  elapsed=23.5m  ETA=94.1m
#
# {'loss': 0.6894, 'grad_norm': 10.357314598058888, 'learning_rate': 4.665063509461098e-06, 'completion_length': 119.75, 'rewards/accuracy_reward': 0.625, 'rewards/format_reward': 0.5799479484558105, 'reward': 0.5854687690734863, 'reward_std': 1.4972708225250244, 'kl': 0.0146484375, 'epoch': 0.2}
#
#  20%|██        | 10/50 [18:08<1:02:38, 93.97s/it]/usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#
#  22%|██▏       | 11/50 [21:57<1:28:00, 135.40s/it]
# [██████░░░░░░░░░░░░░░░░░░░░░░] 11/50 ( 22.0%)  elapsed=27.4m  ETA=97.0m
#
# {'loss': -0.1622, 'grad_norm': 12.985740527202351, 'learning_rate': 4.578674030756364e-06, 'completion_length': 87.25, 'rewards/accuracy_reward': 0.25, 'rewards/format_reward': 0.476666659116745, 'reward': -0.40718749165534973, 'reward_std': 1.3975335359573364, 'kl': 0.0245361328125, 'epoch': 0.22}
#
#  22%|██▏       | 11/50 [21:57<1:28:00, 135.40s/it]
#  24%|██▍       | 12/50 [23:54<1:22:13, 129.82s/it]
# [██████░░░░░░░░░░░░░░░░░░░░░░] 12/50 ( 24.0%)  elapsed=29.3m  ETA=92.8m
#
# {'loss': 0.6948, 'grad_norm': 7.266482184108152, 'learning_rate': 4.4833833507280884e-06, 'completion_length': 190.0, 'rewards/accuracy_reward': 0.625, 'rewards/format_reward': 0.7741146087646484, 'reward': 0.8190104961395264, 'reward_std': 1.3243855237960815, 'kl': 0.0211181640625, 'epoch': 0.24}
#
#  24%|██▍       | 12/50 [23:54<1:22:13, 129.82s/it]
#  26%|██▌       | 13/50 [25:07<1:09:17, 112.37s/it]
# [███████░░░░░░░░░░░░░░░░░░░░░] 13/50 ( 26.0%)  elapsed=30.5m  ETA=86.8m
#
# {'loss': -0.7013, 'grad_norm': 11.257072300425879, 'learning_rate': 4.379599518697444e-06, 'completion_length': 92.75, 'rewards/accuracy_reward': 0.375, 'rewards/format_reward': 0.6395833492279053, 'reward': 0.1834374964237213, 'reward_std': 1.174329400062561, 'kl': 0.03759765625, 'epoch': 0.26}
#
#  26%|██▌       | 13/50 [25:07<1:09:17, 112.37s/it]
#  28%|██▊       | 14/50 [26:49<1:05:34, 109.30s/it]
# [███████░░░░░░░░░░░░░░░░░░░░░] 14/50 ( 28.0%)  elapsed=32.2m  ETA=82.8m
#
# {'loss': -0.5233, 'grad_norm': 8.466132057855477, 'learning_rate': 4.267766952966369e-06, 'completion_length': 133.75, 'rewards/accuracy_reward': 0.5, 'rewards/format_reward': 0.6378124952316284, 'reward': 0.34583336114883423, 'reward_std': 1.2383192777633667, 'kl': 0.043212890625, 'epoch': 0.28}
#
#  28%|██▊       | 14/50 [26:49<1:05:34, 109.30s/it]
#  30%|███       | 15/50 [28:00<57:07, 97.94s/it]
# [████████░░░░░░░░░░░░░░░░░░░░] 15/50 ( 30.0%)  elapsed=33.4m  ETA=77.9m
#
# {'loss': 0.6996, 'grad_norm': 8.424539148534278, 'learning_rate': 4.1483645377501726e-06, 'completion_length': 116.0, 'rewards/accuracy_reward': 0.625, 'rewards/format_reward': 0.6292188167572021, 'reward': 0.7403645515441895, 'reward_std': 1.1811728477478027, 'kl': 0.03369140625, 'epoch': 0.3}
#
#  30%|███       | 15/50 [28:00<57:07, 97.94s/it]
#  32%|███▏      | 16/50 [29:23<52:49, 93.22s/it]
# [████████░░░░░░░░░░░░░░░░░░░░] 16/50 ( 32.0%)  elapsed=34.8m  ETA=73.9m
#
# {'loss': -0.3079, 'grad_norm': 10.771078863020191, 'learning_rate': 4.021903572521802e-06, 'completion_length': 124.5, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.6630208492279053, 'reward': -0.3772916793823242, 'reward_std': 0.8189994096755981, 'kl': 0.035888671875, 'epoch': 0.32}
#
#  32%|███▏      | 16/50 [29:23<52:49, 93.22s/it]
#  34%|███▍      | 17/50 [30:39<48:24, 88.01s/it]
# [█████████░░░░░░░░░░░░░░░░░░░] 17/50 ( 34.0%)  elapsed=36.0m  ETA=70.0m
#
# {'loss': 0.1691, 'grad_norm': 11.199821746994052, 'learning_rate': 3.888925582549006e-06, 'completion_length': 97.75, 'rewards/accuracy_reward': 0.0, 'rewards/format_reward': 0.6390104293823242, 'reward': -0.6390104293823242, 'reward_std': 0.08091732859611511, 'kl': 0.0771484375, 'epoch': 0.34}
#
#  34%|███▍      | 17/50 [30:39<48:24, 88.01s/it]
#  36%|███▌      | 18/50 [31:44<43:16, 81.13s/it]
# [██████████░░░░░░░░░░░░░░░░░░] 18/50 ( 36.0%)  elapsed=37.1m  ETA=66.0m
#
# {'loss': -0.6822, 'grad_norm': 12.554339792228944, 'learning_rate': 3.7500000000000005e-06, 'completion_length': 75.75, 'rewards/accuracy_reward': 0.375, 'rewards/format_reward': 0.6142187118530273, 'reward': 0.20244789123535156, 'reward_std': 1.1488662958145142, 'kl': 0.0751953125, 'epoch': 0.36}
#
#  36%|███▌      | 18/50 [31:44<43:16, 81.13s/it]
#  38%|███▊      | 19/50 [32:48<39:21, 76.18s/it]
# [██████████░░░░░░░░░░░░░░░░░░] 19/50 ( 38.0%)  elapsed=38.2m  ETA=62.3m
#
# {'loss': -0.2783, 'grad_norm': 18.329880529356064, 'learning_rate': 3.6057217255475034e-06, 'completion_length': 90.75, 'rewards/accuracy_reward': 0.25, 'rewards/format_reward': 0.5476042032241821, 'reward': -0.22177086770534515, 'reward_std': 1.2535659074783325, 'kl': 0.1005859375, 'epoch': 0.38}
#
#  38%|███▊      | 19/50 [32:48<39:21, 76.18s/it]
#  40%|████      | 20/50 [33:39<34:17, 68.57s/it]
# [███████████░░░░░░░░░░░░░░░░░] 20/50 ( 40.0%)  elapsed=39.0m  ETA=58.6m
#
# {'loss': 0.7126, 'grad_norm': 14.321114246204681, 'learning_rate': 3.4567085809127247e-06, 'completion_length': 64.0, 'rewards/accuracy_reward': 0.625, 'rewards/format_reward': 0.5683333873748779, 'reward': 0.7540625333786011, 'reward_std': 1.1100720167160034, 'kl': 0.1337890625, 'epoch': 0.4}
#
#  40%|████      | 20/50 [33:39<34:17, 68.57s/it]/usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#
#  42%|████▏     | 21/50 [37:29<56:34, 117.04s/it]
# [███████████░░░░░░░░░░░░░░░░░] 21/50 ( 42.0%)  elapsed=42.9m  ETA=59.2m
#
# {'loss': 0.1045, 'grad_norm': 13.378941404956802, 'learning_rate': 3.303598663257904e-06, 'completion_length': 58.75, 'rewards/accuracy_reward': 0.0, 'rewards/format_reward': 0.5804687738418579, 'reward': -0.5804687738418579, 'reward_std': 0.02296741120517254, 'kl': 0.10400390625, 'epoch': 0.42}
#
#  42%|████▏     | 21/50 [37:29<56:34, 117.04s/it]
#  44%|████▍     | 22/50 [38:21<45:25, 97.33s/it]
# [████████████░░░░░░░░░░░░░░░░] 22/50 ( 44.0%)  elapsed=43.7m  ETA=55.7m
#
# {'loss': 0.3105, 'grad_norm': 12.922533450659273, 'learning_rate': 3.147047612756302e-06, 'completion_length': 61.25, 'rewards/accuracy_reward': 0.875, 'rewards/format_reward': 0.5751562118530273, 'reward': 1.3051562309265137, 'reward_std': 0.762776792049408, 'kl': 0.0927734375, 'epoch': 0.44}
#
#  44%|████▍     | 22/50 [38:21<45:25, 97.33s/it]
#  46%|████▌     | 23/50 [39:18<38:28, 85.49s/it]
# [████████████░░░░░░░░░░░░░░░░] 23/50 ( 46.0%)  elapsed=44.7m  ETA=52.5m
#
# {'loss': -0.3009, 'grad_norm': 13.650340149681794, 'learning_rate': 2.9877258050403214e-06, 'completion_length': 74.75, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.58203125, 'reward': -0.31588539481163025, 'reward_std': 0.7621126174926758, 'kl': 0.08935546875, 'epoch': 0.46}
#
#  46%|████▌     | 23/50 [39:18<38:28, 85.49s/it]
#  48%|████▊     | 24/50 [40:10<32:39, 75.38s/it]
# [█████████████░░░░░░░░░░░░░░░] 24/50 ( 48.0%)  elapsed=45.6m  ETA=49.4m
#
# {'loss': 0.2426, 'grad_norm': 24.725648864936506, 'learning_rate': 2.82631548055013e-06, 'completion_length': 61.75, 'rewards/accuracy_reward': 1.0, 'rewards/format_reward': 0.5022395849227905, 'reward': 1.502239465713501, 'reward_std': 0.20553989708423615, 'kl': 0.1357421875, 'epoch': 0.48}
#
#  48%|████▊     | 24/50 [40:10<32:39, 75.38s/it]
#  50%|█████     | 25/50 [41:19<30:34, 73.40s/it]
# [██████████████░░░░░░░░░░░░░░] 25/50 ( 50.0%)  elapsed=46.7m  ETA=46.7m
#
# {'loss': -0.5037, 'grad_norm': 10.427420395693991, 'learning_rate': 2.663507823075358e-06, 'completion_length': 101.25, 'rewards/accuracy_reward': 0.25, 'rewards/format_reward': 0.6078125238418579, 'reward': -0.010208353400230408, 'reward_std': 1.053609013557434, 'kl': 0.0888671875, 'epoch': 0.5}
#
#  50%|█████     | 25/50 [41:19<30:34, 73.40s/it]
#  52%|█████▏    | 26/50 [42:16<27:22, 68.45s/it]
# [██████████████░░░░░░░░░░░░░░] 26/50 ( 52.0%)  elapsed=47.7m  ETA=44.0m
#
# {'loss': 0.027, 'grad_norm': 9.315544478736774, 'learning_rate': 2.5e-06, 'completion_length': 75.75, 'rewards/accuracy_reward': 0.5, 'rewards/format_reward': 0.5848437547683716, 'reward': 0.48776042461395264, 'reward_std': 1.1606775522232056, 'kl': 0.162109375, 'epoch': 0.52}
#
#  52%|█████▏    | 26/50 [42:16<27:22, 68.45s/it]
#  54%|█████▍    | 27/50 [43:09<24:28, 63.86s/it]
# [███████████████░░░░░░░░░░░░░] 27/50 ( 54.0%)  elapsed=48.5m  ETA=41.4m
#
# {'loss': -0.1532, 'grad_norm': 13.560636158306867, 'learning_rate': 2.3364921769246423e-06, 'completion_length': 62.5, 'rewards/accuracy_reward': 1.0, 'rewards/format_reward': 0.58161461353302, 'reward': 1.58161461353302, 'reward_std': 0.044789254665374756, 'kl': 0.1201171875, 'epoch': 0.54}
#
#  54%|█████▍    | 27/50 [43:09<24:28, 63.86s/it]
#  56%|█████▌    | 28/50 [44:03<22:17, 60.79s/it]
# [███████████████░░░░░░░░░░░░░] 28/50 ( 56.0%)  elapsed=49.4m  ETA=38.8m
#
# {'loss': 0.3395, 'grad_norm': 9.17348860157075, 'learning_rate': 2.173684519449872e-06, 'completion_length': 67.75, 'rewards/accuracy_reward': 0.875, 'rewards/format_reward': 0.5826562643051147, 'reward': 1.267031192779541, 'reward_std': 0.8202421069145203, 'kl': 0.115234375, 'epoch': 0.56}
#
#  56%|█████▌    | 28/50 [44:03<22:17, 60.79s/it]
#  58%|█████▊    | 29/50 [44:51<19:56, 56.98s/it]
# [████████████████░░░░░░░░░░░░] 29/50 ( 58.0%)  elapsed=50.2m  ETA=36.4m
#
# {'loss': -0.3372, 'grad_norm': 21.620120602105406, 'learning_rate': 2.01227419495968e-06, 'completion_length': 51.0, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.5643750429153442, 'reward': -0.3009374737739563, 'reward_std': 0.7496070861816406, 'kl': 0.1435546875, 'epoch': 0.58}
#
#  58%|█████▊    | 29/50 [44:51<19:56, 56.98s/it]
#  60%|██████    | 30/50 [45:40<18:10, 54.50s/it]
# [████████████████░░░░░░░░░░░░] 30/50 ( 60.0%)  elapsed=51.1m  ETA=34.0m
#
# {'loss': 0.0677, 'grad_norm': 16.287772867835088, 'learning_rate': 1.852952387243698e-06, 'completion_length': 47.25, 'rewards/accuracy_reward': 1.0, 'rewards/format_reward': 0.5666146278381348, 'reward': 1.5666146278381348, 'reward_std': 0.020164787769317627, 'kl': 0.1474609375, 'epoch': 0.6}
#
#  60%|██████    | 30/50 [45:40<18:10, 54.50s/it]/usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#
#  62%|██████▏   | 31/50 [49:13<32:22, 102.25s/it]
# [█████████████████░░░░░░░░░░░] 31/50 ( 62.0%)  elapsed=54.6m  ETA=33.5m
#
# {'loss': 0.3222, 'grad_norm': 16.133644978585053, 'learning_rate': 1.6964013367420967e-06, 'completion_length': 56.75, 'rewards/accuracy_reward': 0.875, 'rewards/format_reward': 0.5671353936195374, 'reward': 1.3018229007720947, 'reward_std': 0.7533844709396362, 'kl': 0.115234375, 'epoch': 0.62}
#
#  62%|██████▏   | 31/50 [49:13<32:22, 102.25s/it]
#  64%|██████▍   | 32/50 [50:04<26:03, 86.85s/it]
# [█████████████████░░░░░░░░░░░] 32/50 ( 64.0%)  elapsed=55.5m  ETA=31.2m
#
# {'loss': -0.3347, 'grad_norm': 16.4396999334142, 'learning_rate': 1.5432914190872757e-06, 'completion_length': 58.25, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.5784895420074463, 'reward': -0.3109895884990692, 'reward_std': 0.7606729865074158, 'kl': 0.1611328125, 'epoch': 0.64}
#
#  64%|██████▍   | 32/50 [50:04<26:03, 86.85s/it]
#  66%|██████▌   | 33/50 [51:04<22:19, 78.80s/it]
# [██████████████████░░░░░░░░░░] 33/50 ( 66.0%)  elapsed=56.5m  ETA=29.1m
#
# {'loss': -0.1213, 'grad_norm': 14.526734883331075, 'learning_rate': 1.3942782744524974e-06, 'completion_length': 61.5, 'rewards/accuracy_reward': 1.0, 'rewards/format_reward': 0.5817188024520874, 'reward': 1.5817188024520874, 'reward_std': 0.03542714565992355, 'kl': 0.13671875, 'epoch': 0.66}
#
#  66%|██████▌   | 33/50 [51:04<22:19, 78.80s/it]
#  68%|██████▊   | 34/50 [52:01<19:13, 72.12s/it]
# [███████████████████░░░░░░░░░] 34/50 ( 68.0%)  elapsed=57.4m  ETA=27.0m
#
# {'loss': 0.2307, 'grad_norm': 13.819077115330384, 'learning_rate': 1.2500000000000007e-06, 'completion_length': 64.75, 'rewards/accuracy_reward': 0.0, 'rewards/format_reward': 0.5950521230697632, 'reward': -0.5950521230697632, 'reward_std': 0.04017842933535576, 'kl': 0.220703125, 'epoch': 0.68}
#
#  68%|██████▊   | 34/50 [52:01<19:13, 72.12s/it]
#  70%|███████   | 35/50 [53:01<17:10, 68.70s/it]
# [███████████████████░░░░░░░░░] 35/50 ( 70.0%)  elapsed=58.4m  ETA=25.0m
#
# {'loss': -0.5308, 'grad_norm': 16.38935949144455, 'learning_rate': 1.1110744174509952e-06, 'completion_length': 66.25, 'rewards/accuracy_reward': 0.25, 'rewards/format_reward': 0.5938020944595337, 'reward': -0.05411456525325775, 'reward_std': 1.008621096611023, 'kl': 0.173828125, 'epoch': 0.7}
#
#  70%|███████   | 35/50 [53:01<17:10, 68.70s/it]
#  72%|███████▏  | 36/50 [54:23<16:57, 72.69s/it]
# [████████████████████░░░░░░░░] 36/50 ( 72.0%)  elapsed=59.8m  ETA=23.2m
#
# {'loss': -0.1922, 'grad_norm': 10.632934137277738, 'learning_rate': 9.780964274781984e-07, 'completion_length': 101.75, 'rewards/accuracy_reward': 1.0, 'rewards/format_reward': 0.6605208516120911, 'reward': 1.6605207920074463, 'reward_std': 0.06427627056837082, 'kl': 0.076171875, 'epoch': 0.72}
#
#  72%|███████▏  | 36/50 [54:23<16:57, 72.69s/it]
#  74%|███████▍  | 37/50 [55:23<14:53, 68.72s/it]
# [████████████████████░░░░░░░░] 37/50 ( 74.0%)  elapsed=60.8m  ETA=21.4m
#
# {'loss': -0.7273, 'grad_norm': 13.446270733100265, 'learning_rate': 8.516354622498279e-07, 'completion_length': 66.25, 'rewards/accuracy_reward': 0.375, 'rewards/format_reward': 0.5926041603088379, 'reward': 0.2305208444595337, 'reward_std': 1.1323490142822266, 'kl': 0.1083984375, 'epoch': 0.74}
#
#  74%|███████▍  | 37/50 [55:23<14:53, 68.72s/it]
#  76%|███████▌  | 38/50 [57:42<17:58, 89.89s/it]
# [█████████████████████░░░░░░░] 38/50 ( 76.0%)  elapsed=63.1m  ETA=19.9m
#
# {'loss': 0.5063, 'grad_norm': 14.362339578088907, 'learning_rate': 7.322330470336314e-07, 'completion_length': 67.5, 'rewards/accuracy_reward': 0.75, 'rewards/format_reward': 0.5818228721618652, 'reward': 1.0497395992279053, 'reward_std': 0.9970799684524536, 'kl': 0.15234375, 'epoch': 0.76}
#
#  76%|███████▌  | 38/50 [57:42<17:58, 89.89s/it]
#  78%|███████▊  | 39/50 [58:46<15:03, 82.11s/it]
# [█████████████████████░░░░░░░] 39/50 ( 78.0%)  elapsed=64.2m  ETA=18.1m
#
# {'loss': -0.7033, 'grad_norm': 14.019120379733918, 'learning_rate': 6.204004813025569e-07, 'completion_length': 62.25, 'rewards/accuracy_reward': 0.375, 'rewards/format_reward': 0.6072916388511658, 'reward': 0.20343750715255737, 'reward_std': 1.1412298679351807, 'kl': 0.171875, 'epoch': 0.78}
#
#  78%|███████▊  | 39/50 [58:46<15:03, 82.11s/it]
#  80%|████████  | 40/50 [59:51<12:49, 76.91s/it]
# [██████████████████████░░░░░░] 40/50 ( 80.0%)  elapsed=65.2m  ETA=16.3m
#
# {'loss': 0.5351, 'grad_norm': 13.614105865313688, 'learning_rate': 5.166166492719124e-07, 'completion_length': 74.5, 'rewards/accuracy_reward': 0.75, 'rewards/format_reward': 0.6054166555404663, 'reward': 1.0559375286102295, 'reward_std': 1.0218908786773682, 'kl': 0.1142578125, 'epoch': 0.8}
#
#  80%|████████  | 40/50 [59:51<12:49, 76.91s/it]/usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#
#  82%|████████▏ | 41/50 [1:03:42<18:28, 123.16s/it]
# [██████████████████████░░░░░░] 41/50 ( 82.0%)  elapsed=69.1m  ETA=15.2m
#
# {'loss': 0.5245, 'grad_norm': 12.855988338854297, 'learning_rate': 4.2132596924363666e-07, 'completion_length': 89.0, 'rewards/accuracy_reward': 0.75, 'rewards/format_reward': 0.6162499785423279, 'reward': 1.0630208253860474, 'reward_std': 1.0310242176055908, 'kl': 0.1083984375, 'epoch': 0.82}
#
#  82%|████████▏ | 41/50 [1:03:42<18:28, 123.16s/it]
#  84%|████████▍ | 42/50 [1:04:42<13:54, 104.27s/it]
# [███████████████████████░░░░░] 42/50 ( 84.0%)  elapsed=70.1m  ETA=13.4m
#
# {'loss': -0.4955, 'grad_norm': 10.681149846762386, 'learning_rate': 3.3493649053890325e-07, 'completion_length': 74.75, 'rewards/accuracy_reward': 0.25, 'rewards/format_reward': 0.6003124713897705, 'reward': -0.03427082300186157, 'reward_std': 1.0288500785827637, 'kl': 0.1025390625, 'epoch': 0.84}
#
#  84%|████████▍ | 42/50 [1:04:42<13:54, 104.27s/it]
#  86%|████████▌ | 43/50 [1:05:41<10:33, 90.56s/it]
# [████████████████████████░░░░] 43/50 ( 86.0%)  elapsed=71.1m  ETA=11.6m
#
# {'loss': -0.3047, 'grad_norm': 13.600757085403753, 'learning_rate': 2.5781814616827936e-07, 'completion_length': 77.25, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.6026562452316284, 'reward': -0.3318229019641876, 'reward_std': 0.7753519415855408, 'kl': 0.123046875, 'epoch': 0.86}
#
#  86%|████████▌ | 43/50 [1:05:41<10:33, 90.56s/it]
#  88%|████████▊ | 44/50 [1:06:54<08:31, 85.26s/it]
# [████████████████████████░░░░] 44/50 ( 88.0%)  elapsed=72.3m  ETA=9.9m
#
# {'loss': -0.3107, 'grad_norm': 11.451806443052494, 'learning_rate': 1.9030116872178317e-07, 'completion_length': 97.75, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.6332812309265137, 'reward': -0.3436979055404663, 'reward_std': 0.8106805682182312, 'kl': 0.10107421875, 'epoch': 0.88}
#
#  88%|████████▊ | 44/50 [1:06:54<08:31, 85.26s/it]
#  90%|█████████ | 45/50 [1:08:08<06:49, 81.93s/it]
# [█████████████████████████░░░] 45/50 ( 90.0%)  elapsed=73.5m  ETA=8.2m
#
# {'loss': 0.6926, 'grad_norm': 11.046569470526608, 'learning_rate': 1.3267467626223606e-07, 'completion_length': 94.75, 'rewards/accuracy_reward': 0.625, 'rewards/format_reward': 0.6318750381469727, 'reward': 0.7866666316986084, 'reward_std': 1.172512412071228, 'kl': 0.1083984375, 'epoch': 0.9}
#
#  90%|█████████ | 45/50 [1:08:08<06:49, 81.93s/it]
#  92%|█████████▏| 46/50 [1:09:10<05:03, 75.89s/it]
# [█████████████████████████░░░] 46/50 ( 92.0%)  elapsed=74.6m  ETA=6.5m
#
# {'loss': 0.3273, 'grad_norm': 12.788145324538402, 'learning_rate': 8.518543427732951e-08, 'completion_length': 80.75, 'rewards/accuracy_reward': 0.875, 'rewards/format_reward': 0.5969271063804626, 'reward': 1.3195312023162842, 'reward_std': 0.7808054089546204, 'kl': 0.12158203125, 'epoch': 0.92}
#
#  92%|█████████▏| 46/50 [1:09:10<05:03, 75.89s/it]
#  94%|█████████▍| 47/50 [1:10:11<03:34, 71.66s/it]
# [██████████████████████████░░] 47/50 ( 94.0%)  elapsed=75.6m  ETA=4.8m
#
# {'loss': -0.3065, 'grad_norm': 17.668119573753184, 'learning_rate': 4.8036798991923925e-08, 'completion_length': 80.25, 'rewards/accuracy_reward': 0.125, 'rewards/format_reward': 0.60505211353302, 'reward': -0.34057295322418213, 'reward_std': 0.7685364484786987, 'kl': 0.123046875, 'epoch': 0.94}
#
#  94%|█████████▍| 47/50 [1:10:11<03:34, 71.66s/it]
#  96%|█████████▌| 48/50 [1:11:17<02:19, 69.86s/it]
# [██████████████████████████░░] 48/50 ( 96.0%)  elapsed=76.7m  ETA=3.2m
#
# {'loss': -0.7183, 'grad_norm': 10.783609423353706, 'learning_rate': 2.1387846565474047e-08, 'completion_length': 77.5, 'rewards/accuracy_reward': 0.375, 'rewards/format_reward': 0.6043750047683716, 'reward': 0.23354165256023407, 'reward_std': 1.1461917161941528, 'kl': 0.1435546875, 'epoch': 0.96}
#
#  96%|█████████▌| 48/50 [1:11:17<02:19, 69.86s/it]
#  98%|█████████▊| 49/50 [1:12:15<01:06, 66.22s/it]
# [███████████████████████████░] 49/50 ( 98.0%)  elapsed=77.6m  ETA=1.6m
#
# {'loss': 0.7002, 'grad_norm': 13.946467761101113, 'learning_rate': 5.352691903491303e-09, 'completion_length': 63.75, 'rewards/accuracy_reward': 0.625, 'rewards/format_reward': 0.5986979007720947, 'reward': 0.7846353650093079, 'reward_std': 1.1352856159210205, 'kl': 0.146484375, 'epoch': 0.98}
#
#  98%|█████████▊| 49/50 [1:12:15<01:06, 66.22s/it]
# 100%|██████████| 50/50 [1:13:30<00:00, 68.94s/it]
# [████████████████████████████] 50/50 (100.0%)  elapsed=78.9m  ETA=0.0m
#
# {'loss': 0.7339, 'grad_norm': 9.996612479780199, 'learning_rate': 0.0, 'completion_length': 92.75, 'rewards/accuracy_reward': 0.625, 'rewards/format_reward': 0.6362500190734863, 'reward': 0.7631250619888306, 'reward_std': 1.1825367212295532, 'kl': 0.1220703125, 'epoch': 1.0}
#
# 100%|██████████| 50/50 [1:13:30<00:00, 68.94s/it]
#
# {'train_runtime': 4616.3604, 'train_samples_per_second': 0.011, 'train_steps_per_second': 0.011, 'train_loss': -0.005325365662574768, 'epoch': 1.0}
#
# 100%|██████████| 50/50 [1:16:56<00:00, 68.94s/it]
# 100%|██████████| 50/50 [1:16:56<00:00, 92.33s/it]
# [2026-07-17 08:37:16,309] [INFO] [launch.py:351:main] Process 33646 exits successfully.
# [████████████████████████████] 50/50 (100.0%)  elapsed=83.3m  ETA=0.0m  done
# 训练完成: /content/drive/MyDrive/MixUpLLaVA-video-r1/outputs/grpo_CPPO_g8_p50 | wall=83.3 min
